# %% [markdown]
# The goal for this project is to do a competitive analysis for the business market in the united states, so for people who are interested in opening up new businesses in the U.S. they will have a better understanding of the market.

# %% [markdown]
# # Import business.json data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pymysql 
import json
import csv
import random
import string
import pandas.io.sql as pdSQL

# %% [markdown]
# We started by getting the data from yelp's database.

# %%
mydf = pd.read_json('/Users/macbookair/Downloads/dataset 2/business.json', lines= True)

# %%
mydf
# Out:
#                                            address  \
# 0                                  691 Richmond Rd
# 1                                   2824 Milton Rd
# 2                              337 Danforth Avenue
# 3              7702 E Doubletree Ranch Rd, Ste 300
# 4                                   4719 N 20Th St
# 5                              2017 E Camelback Rd
# 6                          4425 N 24th St, Ste 125
# 7                                   5770 Butler St
# 8                               3220 Washington Rd
# 9                        1425 S Higley Rd, Ste 103
# 10                         11022 W Charleston Blvd
# 11                         9393 N 90th St, Ste 112
# 12                              9101 E Baseline Rd
# 13                                 12417 W Pima St
# 14                        9616 E Independence Blvd
# 15                                 190 E Dallas Rd
# 16                                        62 S Ctr
# 17                        2128 Warrensville Ctr Rd
# 18                                  3710 Payne Ave
# 19                              2385 E Windmill Ln
# 20                         10515 B Centrum Parkway
# 21                                4759 Liberty Ave
# 22                    7070 Saint Barbara Boulevard
# 23                     1111 N Gilbert Rd, Ste 212A
# 24
# 25                                 43 Leith Street
# 26                             7 Hart House Circle
# 27                                   1663 St-Denis
# 28                                 6021 Centre Ave
# 29                 15323 N. Scottsdale Rd, Ste 110
# ...                                            ...
# 156609                                 31 E 5th St
# 156610                       1800 Las Vegas Blvd S
# 156611                  4130 S Sandhill Rd, Ste A5
# 156612                        401 E Bell Rd, Ste 5
# 156613                          18 Tank House Lane
# 156614                    4924 Sherbrooke Street W
# 156615                             5680 S Pecos Rd
# 156616                    5868 S Pecos Rd, Ste 200
# 156617                   674-676 Sheppard Avenue W
# 156618                 1371 Rue Sainte-Catherine E
# 156619              12614 N Cave Creek Rd, Ste 108
# 156620                      7101 W Craig Rd, Ste 1
# 156621               15605 W Roosevelt St, Ste 106
# 156622           2930 W Horizon Ridge Pky, Ste 100
# 156623                  316 E Bridger Ave, Ste 101
# 156624                             10659 Grand Ave
# 156625                    9335 N Tryon St, Ste 102
# 156626                               2401 Penn Ave
# 156627                            16880 N 59th Ave
# 156628        7700 W Arrowhead Towne Ctr, Ste 2049
# 156629               6033 W Bell Rd, Bldg D, Ste F
# 156630                 5293 Highway 7 E, Suite 204
# 156631                         1925 St.Catherine W
# 156632                           2419 Yonge Street
# 156633                          9812 Rea Rd, Ste A
# 156634                         1103 Queen Street E
# 156635  Star Trek The Experience, 3000 Paradise Rd
# 156636                               1833 E 3rd St
# 156637                       The Croft Drumsmittal
# 156638                                540 Marks St
#
#                                                attributes  \
# 0       {'RestaurantsPriceRange2': 2, 'BikeParking': T...
# 1       {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 2       {'BusinessParking': {'garage': False, 'validat...
# 3                                                      {}
# 4       {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 5       {'RestaurantsPriceRange2': 2, 'BusinessAccepts...
# 6       {'ByAppointmentOnly': True, 'BusinessAcceptsCr...
# 7                    {'BusinessAcceptsCreditCards': True}
# 8       {'BusinessParking': {'garage': False, 'validat...
# 9       {'ByAppointmentOnly': True, 'BusinessAcceptsCr...
# 10      {'BusinessParking': {'garage': True, 'validate...
# 11      {'BusinessParking': {'garage': False, 'validat...
# 12      {'BusinessParking': {'garage': False, 'validat...
# 13      {'BusinessAcceptsBitcoin': False, 'ByAppointme...
# 14      {'BusinessParking': {'garage': False, 'validat...
# 15      {'RestaurantsAttire': 'casual', 'Alcohol': 'no...
# 16      {'ByAppointmentOnly': True, 'BusinessAcceptsCr...
# 17                   {'BusinessAcceptsCreditCards': True}
# 18      {'BusinessParking': {'garage': False, 'validat...
# 19                                                     {}
# 20                   {'BusinessAcceptsCreditCards': True}
# 21      {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 22      {'HasTV': True, 'RestaurantsAttire': 'casual',...
# 23                            {'ByAppointmentOnly': True}
# 24                                                     {}
# 25      {'BusinessParking': {'garage': False, 'lot': F...
# 26                                  {'GoodForKids': True}
# 27      {'RestaurantsPriceRange2': 2, 'BusinessAccepts...
# 28      {'BusinessParking': {'garage': False, 'validat...
# 29      {'ByAppointmentOnly': False, 'BusinessAcceptsC...
# ...                                                   ...
# 156609                                                 {}
# 156610  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156611  {'BusinessParking': {'garage': False, 'validat...
# 156612  {'BusinessParking': {'garage': False, 'validat...
# 156613  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156614  {'BusinessParking': {'garage': False, 'validat...
# 156615  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156616                                                 {}
# 156617  {'RestaurantsPriceRange2': 1, 'GoodForKids': T...
# 156618  {'Ambience': {'romantic': False, 'upscale': Fa...
# 156619               {'BusinessAcceptsCreditCards': True}
# 156620  {'RestaurantsPriceRange2': 2, 'WiFi': 'free', ...
# 156621  {'HasTV': True, 'RestaurantsAttire': 'casual',...
# 156622  {'ByAppointmentOnly': True, 'BusinessAcceptsCr...
# 156623  {'BusinessAcceptsBitcoin': False, 'BusinessAcc...
# 156624  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156625  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156626  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156627  {'RestaurantsPriceRange2': 2, 'BusinessAccepts...
# 156628                                                 {}
# 156629  {'BusinessParking': {'garage': False, 'validat...
# 156630                        {'ByAppointmentOnly': True}
# 156631  {'BusinessParking': {'garage': False, 'validat...
# 156632  {'HasTV': True, 'RestaurantsAttire': 'casual',...
# 156633  {'BusinessParking': {'garage': False, 'validat...
# 156634  {'BusinessParking': {'garage': False, 'validat...
# 156635  {'BusinessParking': {'garage': False, 'validat...
# 156636                                                 {}
# 156637                                                 {}
# 156638  {'RestaurantsPriceRange2': 1, 'BusinessAccepts...
#
#                    business_id  \
# 0       YDf95gJZaq05wvo7hTQbbQ
# 1       mLwM-h2YhXl2NCgdS84_Bw
# 2       v2WhjAB3PIBA8J8VxG3wEg
# 3       CVtCbSB1zUcUWg-9TNGTuQ
# 4       duHFBe87uNSXImQmvBh87Q
# 5       uUEMrhJiL1a1pCA_I1SU7Q
# 6       2eJEUJIP54tex7T9YOcLSw
# 7       fEylCY3UEH8YJ0Xa7lu6lA
# 8       kFtuYklkAIlmYw8RZAieGw
# 156630  [Massage, Chiropractors, Health & Medical, Bea...           Markham
# 156631  [Food, Taiwanese, Restaurants, Coffee & Tea, C...          Montréal
# 156632                             [Restaurants, Burgers]           Toronto
# 156633             [Day Spas, Beauty & Spas, Hair Salons]         Charlotte
# 156634  [Art Galleries, Flowers & Gifts, Event Plannin...           Toronto
# 156635                      [American (New), Restaurants]         Las Vegas
# 156636                          [Auto Repair, Automotive]             Tempe
# 156637                                [Zoos, Active Life]         Inverness
# 156638  [Fashion, Shopping, Food, Department Stores, M...         Henderson
#
#                                                     hours  is_open   latitude  \
# 0       {'Tuesday': '10:00-21:00', 'Monday': '10:00-21...        1  41.541716
# 1       {'Tuesday': '10:00-22:00', 'Monday': '10:00-22...        0  35.236870
# 2       {'Tuesday': '10:00-19:00', 'Monday': '10:00-19...        0  43.677126
# 3       {'Tuesday': '9:00-17:00', 'Thursday': '9:00-17...        1  33.565082
# 4                                                      {}        0  33.505928
# 5       {'Tuesday': '10:00-20:00', 'Monday': '10:00-20...        0  33.508068
# 6       {'Tuesday': '14:00-19:00', 'Thursday': '14:00-...        1  33.502848
# 7       {'Tuesday': '8:00-17:00', 'Monday': '8:00-17:0...        1  40.485939
# 8       {'Tuesday': '10:00-18:00', 'Monday': '10:00-18...        1  40.290498
# 9       {'Tuesday': '7:30-17:00', 'Thursday': '7:30-17...        1  33.324539
# 10                                                     {}        1  36.159098
# 11      {'Tuesday': '10:00-18:00', 'Monday': '10:00-18...        0  33.570421
# 12      {'Tuesday': '5:00-0:00', 'Monday': '5:00-0:00'...        1  33.377428
# 13      {'Tuesday': '8:00-17:00', 'Monday': '8:00-17:0...        1  33.431335
# 14      {'Tuesday': '11:00-0:00', 'Monday': '11:00-0:0...        1  35.135196
# 15      {'Tuesday': '11:30-22:00', 'Monday': '11:30-22...        1  35.355085
# 16      {'Tuesday': '7:00-19:00', 'Monday': '7:00-19:0...        1  33.413219
# 17      {'Tuesday': '8:30-18:00', 'Monday': '8:30-18:0...        1  41.501820
# 18      {'Monday': '9:00-20:00', 'Saturday': '9:00-20:...        1  41.509408
# 19      {'Tuesday': '10:00-19:00', 'Monday': '10:00-19...        1  36.040413
# 20      {'Tuesday': '8:00-18:00', 'Monday': '8:00-18:0...        1  35.089534
# 21      {'Tuesday': '8:00-12:00', 'Thursday': '8:00-12...        1  40.461350
# 22                                                     {}        1  43.639236
# 23                                                     {}        1  33.370202
# 24      {'Tuesday': '8:00-17:00', 'Monday': '8:00-17:0...        1  33.377892
# 25      {'Tuesday': '12:00-1:00', 'Monday': '12:00-1:0...        1  55.954486
# 26                                                     {}        1  43.663669
# 27      {'Tuesday': '12:00-21:00', 'Monday': '12:00-21...        1  45.515279
# 28      {'Tuesday': '9:00-21:00', 'Monday': '9:00-21:0...        1  40.460239
# 29      {'Tuesday': '10:00-20:00', 'Monday': '10:00-20...        1  33.623655
# ...                                                   ...      ...        ...
# 156609                                                 {}        1  33.424934
# 156610  {'Tuesday': '9:00-9:00', 'Monday': '9:00-9:00'...        1  36.150021
# 156611  {'Tuesday': '12:00-0:00', 'Monday': '12:00-0:0...        1  36.113961
# 156612  {'Tuesday': '9:00-19:00', 'Monday': '9:00-19:0...        1  33.638479
# 156613  {'Tuesday': '12:00-22:00', 'Monday': '12:00-22...        1  43.650741
# 156614  {'Tuesday': '10:00-18:00', 'Monday': '10:00-18...        1  45.477754
# 156615  {'Tuesday': '8:00-18:00', 'Monday': '8:00-18:0...        1  36.086867
# 156616  {'Tuesday': '9:00-17:00', 'Thursday': '9:00-17...        1  36.083392
# 156617                                                 {}        1  43.754927
# 156618  {'Tuesday': '11:00-22:00', 'Monday': '11:00-21...        1  45.520289
# 156619  {'Tuesday': '7:00-18:00', 'Thursday': '7:00-18...        1  33.600877
# 156620  {'Tuesday': '5:00-19:30', 'Monday': '5:00-19:3...        1  36.240136
# 156621                                                 {}        0  33.456435
# 156622  {'Tuesday': '8:00-17:00', 'Thursday': '8:00-17...        1  35.999473
# 156623  {'Tuesday': '0:00-0:00', 'Monday': '0:00-0:00'...        1  36.167682
# 156624  {'Tuesday': '11:00-20:00', 'Monday': '11:00-20...        1  33.600876
# 156625  {'Tuesday': '10:00-1:00', 'Monday': '10:00-1:0...        1  35.313384
# 156626  {'Thursday': '10:00-19:00', 'Saturday': '9:00-...        0  40.453845
# 156627  {'Tuesday': '10:00-21:00', 'Monday': '10:00-21...        0  33.637932
# 156628  {'Tuesday': '10:00-21:00', 'Monday': '10:00-21...        1  33.639791
# 156629  {'Tuesday': '10:00-21:00', 'Monday': '10:00-21...        1  33.637750
# 156630  {'Tuesday': '9:30-19:00', 'Monday': '9:30-19:0...        1  43.867263
# 156631  {'Tuesday': '11:00-0:00', 'Monday': '11:00-0:0...        0  45.492610
# 156632  {'Tuesday': '11:30-21:00', 'Monday': '11:30-21...        0  43.710603
# 156633  {'Tuesday': '9:00-20:00', 'Monday': '9:00-20:0...        1  35.035421
# 156634  {'Tuesday': '12:00-18:00', 'Thursday': '12:00-...        0  43.661834
# 156635                                                 {}        0  36.137112
# 156636                                                 {}        1  33.426949
# 156637                                                 {}        1  57.519612
# 156638                                                 {}        0  36.060708
#
#          longitude                                name  \
# 0       -81.493116                Richmond Town Square
# 1       -80.741976  South Florida Style Chicken & Ribs
# 2       -79.353285                    The Tea Emporium
# 3      -111.916400                            TRUmatch
# 4      -112.038847                             Blimpie
# 5      -112.037552                     Baxter's Cigars
# 6      -112.012696            Back-Health Chiropractic
# 7       -79.943727                       Auto Bathouse
# 8       -80.110021                 JAB Jewelry Designs
# 9      -111.720449          Neighborhood Vision Center
# 10     -115.337915         Red Rock Bowling UYE Part 2
# 11     -111.886492                             Sq Cutz
# 12     -111.638108                             Safeway
# 13     -112.325863            Artificial Grass Masters
# 14      -80.714683                          Applebee's
# 15      -81.087268                        China Garden
# 16     -111.831489              Beach Ventures Roofing
# 17      -81.536776              Alpaul Automobile Wash
# 18      -81.662162                         Koko Bakery
# 19     -115.119104                           U.S. Bank
# 20      -80.876679            Precision Tune Auto Care
# 21      -79.948113                             Rocky's
# 22      -79.716199                           Wild Wing
# 23     -111.789447                    Direct Mindpower
# 24     -111.635017               Premiere Social Media
# 25       -3.187137                   Black Bull Tavern
# 26      -79.394687                  Hart House Theatre
# 27      -73.563548       Chez Geeks Hobby Gaming Store
# 28      -79.924624                         Great Clips
# 29     -111.925137                    The Shade Store®
# ...            ...                                 ...
# 156609 -111.938487    Orbit Bus System - City of Tempe
# 156610 -115.153717                        Tacos Mexico
# 156611 -115.090920                         Insane Inks
# 156612 -112.067228       Sincerely Yours Salon - Hair!
# 156613  -79.358017                El Catrin Destileria
# 156614  -73.604628                      The North Face
# 156615 -115.100505            Hand Car Wash - Sinclair
# 156616 -115.099915            Vladimir Goutsaliouk ESQ
# 156617  -79.442695           Popeyes Louisiana Kitchen
# 156618  -73.554658                           Pachamama
# 156619 -112.037685                         Hon-Amotive
# 156620 -115.248802                           Starbucks
# 156621 -112.394234                     Ivy League Dogs
# 156622 -115.115405            Desert Orthopedic Center
# 156623 -115.143516          Brooks Brothers Bail Bonds
# 156624 -112.287774      Nino's Mexican Food Restaurant
# 156625  -80.743157                   Papa John's Pizza
# 156626  -79.980478                        Steve's Deli
# 156627 -112.188525                       The Roomstore
# 156628 -112.224556            AT&T Authorized Retailer
# 156629 -112.189824                       Ming Foot Spa
# 156630  -79.282783        Markham Chiropractic + Rehab
# 156631  -73.580954             Bubble Thé Resto-Lounge
# 156632  -79.399053                   Gourmet Burger Co
# 156633  -80.806811                       HARMONY SALON
# 156634  -79.335638                   Telegramme Prints
# 156635 -115.152919            Quark's Bar & Restaurant
# 156636 -111.907623          Bill's Bimmers Bmw Service
# 156637   -4.260682            Black Isle wildlife park
# 156638 -115.033241                             Walmart
#
#                          neighborhood postal_code  review_count  stars state
# 0                                           44143            17    2.0    OH
# 1                            Eastland       28215             4    4.5    NC
# 2                           Riverdale     M4K 1N7             7    4.5    ON
# 3                                           85258             3    3.0    AZ
# 4                                           85016            10    4.5    AZ
# 5                                           85016            35    5.0    AZ
# 6                                           85016            19    5.0    AZ
# 7                       Lawrenceville       15201            16    2.5    PA
# 8                                           15317             7    5.0    PA
# 9                                           85296             8    5.0    AZ
# 10                          Summerlin       89135            13    4.5    NV
# 11                                          85258             7    4.5    AZ
# 12                                          85209            21    2.0    AZ
# 13                                          85323            41    4.5    AZ
# 14                                          28105            21    2.0    NC
# 15                                          28164             3    3.0    NC
# 16                                          85210             3    3.5    AZ
# 17                                          44121            25    3.0    OH
# 18                  Goodrich Kirtland       44114           162    4.0    OH
# 19                          Southeast       89123             3    3.5    NV
# 20                                          28134            14    3.0    NC
# 21                         Bloomfield       15224            15    3.0    PA
# 22                 Meadowvale Village     L5W 0E6             6    2.5    ON
# 23                                          85234            33    5.0    AZ
# 24                                          85209             8    5.0    AZ
# 25                                        EH1 3AT            14    4.0   EDH
# 26              University of Toronto     M5S 3H3             8    4.0    ON
# 27                        Ville-Marie     H2X 3K4             3    4.0    QC
# 28                          Shadyside       15206            10    3.5    PA
# 29                                          85254            11    3.5    AZ
# ...                               ...         ...           ...    ...   ...
# 156609                                      85281            23    3.0    AZ
# 156610                                      89104           108    3.0    NV
# 156611                       Eastside       89121             3    5.0    NV
# 156612                                      85022           157    4.5    AZ
# 156613            Distillery District     M5A 3C4           570    3.5    ON
# 156614            Notre-Dame-de-Grâce     H3Z 1H3             4    3.5    QC
# 156615                      Southeast       89120             9    4.5    NV
# 156616                      Southeast       89120             4    5.0    NV
# 156617                                    M3H 2S4             3    2.0    ON
# 156618                    Ville-Marie     H2L 2H7            10    4.5    QC
# 156619                                      85022            15    4.0    AZ
# 156620                      Northwest       89129            22    4.0    NV
# 156621                                      85338            54    4.0    AZ
# 156622                         Anthem       89052            40    3.5    NV
# 156623                       Downtown       89101             5    5.0    NV
# 156624                                      85351            50    3.5    AZ
# 156625                University City       28262             9    2.0    NC
# 156626                 Strip District       15222             3    4.5    PA
# 156627                                      85308            18    1.5    AZ
# 156628                                      85308             3    1.0    AZ
# 156629                                      85308            12    5.0    AZ
# 156630                     Unionville     L3P 7M7             3    4.5    ON
# 156631                    Ville-Marie     H3H 1M3             8    3.0    QC
# 156632  Mount Pleasant and Davisville     M4P 2E7            22    3.0    ON
# 156633                     Ballantyne       28277            14    3.5    NC
# 156634                    Leslieville     M4M 1K7             4    5.0    ON
# 156635                       Eastside       89109            42    4.0    NV
# 156636                                      85281             3    3.5    AZ
# 156637                                    IV1 1XF             8    3.5   HLD
# 156638                                      89014            42    2.5    NV
#
# [156639 rows x 15 columns]

# %% [markdown]
# # Data exploration by python

# %% [markdown]
# First, check the amount of business in the yelp database.

# %%
mydf.shape
# Out:
# (156639, 15)

# %% [markdown]
# From the above, we can see that there are 156639 businesses in the U.S, and below we are going explor the location of the businesses.

# %%
plt.hist(mydf[['city']])
plt.show()

# %%
mydf['city'].value_counts()
# Out:
# Las Vegas                      24768
# Phoenix                        15656
# Toronto                        15483
# Charlotte                       7557
# Scottsdale                      7510
# Pittsburgh                      5688
# Montréal                        5175
# Mesa                            5146
# Henderson                       4130
# Tempe                           3949
# Chandler                        3649
# Edinburgh                       3625
# Cleveland                       2979
# Madison                         2891
# Glendale                        2841
# Gilbert                         2835
# Mississauga                     2316
# Stuttgart                       1975
# Peoria                          1527
# Markham                         1390
# North Las Vegas                 1254
# Champaign                       1084
# North York                       944
# Surprise                         934
# Scarborough                      870
# Richmond Hill                    770
# Concord                          726
# Goodyear                         703
# Brampton                         690
# Vaughan                          650
#                                ...
# Ahwatukee Foothills Village        1
# Woodmere Village                   1
# Saint-Roch-De-L'achigan            1
# Mccandless Township                1
# Plum Boro                          1
# Plieningen                         1
# Indian land                        1
# Chander                            1
# Morgan                             1
# Brunswick Hills                    1
# St-Laurent                         1
# Robinson Town                      1
# NorthYork                          1
# W Henderson                        1
# East Mesa                          1
# Cooksville                         1
# Mayfield Hts                       1
# Elizabeth Township                 1
# Phoniex                            1
# Mount Washington                   1
# Hendserson                         1
# East Credit                        1
# Allegheny                          1
# Malton                             1
# St-Jerome                          1
# Lake Park                          1
# Citibank                           1
# Chatauguay                         1
# Claremont                          1
# Saint Leonard                      1
# Name: city, Length: 1010, dtype: int64

# %% [markdown]
# As we can see Las Vegas has the most amount of business, so it is reasonable to assume that there are a lot of opportunities as well as competitions.
#
# We then graphed the average rating of each business, and found out that most businesses have a score above 3.5. There is no restaurant is ranked from 2.5 to 3.5.

# %%
plt.hist(mydf[['stars']])
plt.show()

# %% [markdown]
# We calculated the mean star of all the businesses, and found out that the average rating of all bussiness is 3.64.

# %%
mydf[['stars']].mean()
# Out:
# stars    3.647154
# dtype: float64

# %% [markdown]
# We then ranked the businesses based on the review count to determin the popularity level of each business. For business with most review, it ranked 1. As we can see from below, there is a negative correlation between review count and rating. It means the more reviews you get, the more likely you are going to be ranked higher.

# %%
mydf['rank'] = mydf['review_count'].rank(ascending=0)
mydf
# Out:
#                                            address  \
# 0                                  691 Richmond Rd
# 1                                   2824 Milton Rd
# 2                              337 Danforth Avenue
# 3              7702 E Doubletree Ranch Rd, Ste 300
# 4                                   4719 N 20Th St
# 5                              2017 E Camelback Rd
# 6                          4425 N 24th St, Ste 125
# 7                                   5770 Butler St
# 8                               3220 Washington Rd
# 9                        1425 S Higley Rd, Ste 103
# 10                         11022 W Charleston Blvd
# 11                         9393 N 90th St, Ste 112
# 12                              9101 E Baseline Rd
# 13                                 12417 W Pima St
# 14                        9616 E Independence Blvd
# 15                                 190 E Dallas Rd
# 16                                        62 S Ctr
# 17                        2128 Warrensville Ctr Rd
# 18                                  3710 Payne Ave
# 19                              2385 E Windmill Ln
# 20                         10515 B Centrum Parkway
# 21                                4759 Liberty Ave
# 22                    7070 Saint Barbara Boulevard
# 23                     1111 N Gilbert Rd, Ste 212A
# 24
# 25                                 43 Leith Street
# 26                             7 Hart House Circle
# 27                                   1663 St-Denis
# 28                                 6021 Centre Ave
# 29                 15323 N. Scottsdale Rd, Ste 110
# ...                                            ...
# 156609                                 31 E 5th St
# 156610                       1800 Las Vegas Blvd S
# 156611                  4130 S Sandhill Rd, Ste A5
# 156612                        401 E Bell Rd, Ste 5
# 156613                          18 Tank House Lane
# 156614                    4924 Sherbrooke Street W
# 156615                             5680 S Pecos Rd
# 156616                    5868 S Pecos Rd, Ste 200
# 156617                   674-676 Sheppard Avenue W
# 156618                 1371 Rue Sainte-Catherine E
# 156619              12614 N Cave Creek Rd, Ste 108
# 156620                      7101 W Craig Rd, Ste 1
# 156621               15605 W Roosevelt St, Ste 106
# 156622           2930 W Horizon Ridge Pky, Ste 100
# 156623                  316 E Bridger Ave, Ste 101
# 156624                             10659 Grand Ave
# 156625                    9335 N Tryon St, Ste 102
# 156626                               2401 Penn Ave
# 156627                            16880 N 59th Ave
# 156628        7700 W Arrowhead Towne Ctr, Ste 2049
# 156629               6033 W Bell Rd, Bldg D, Ste F
# 156630                 5293 Highway 7 E, Suite 204
# 156631                         1925 St.Catherine W
# 156632                           2419 Yonge Street
# 156633                          9812 Rea Rd, Ste A
# 156634                         1103 Queen Street E
# 156635  Star Trek The Experience, 3000 Paradise Rd
# 156636                               1833 E 3rd St
# 156637                       The Croft Drumsmittal
# 156638                                540 Marks St
#
#                                                attributes  \
# 0       {'RestaurantsPriceRange2': 2, 'BikeParking': T...
# 1       {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 2       {'BusinessParking': {'garage': False, 'validat...
# 3                                                      {}
# 4       {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 5       {'RestaurantsPriceRange2': 2, 'BusinessAccepts...
# 6       {'ByAppointmentOnly': True, 'BusinessAcceptsCr...
# 7                    {'BusinessAcceptsCreditCards': True}
# 8       {'BusinessParking': {'garage': False, 'validat...
# 9       {'ByAppointmentOnly': True, 'BusinessAcceptsCr...
# 10      {'BusinessParking': {'garage': True, 'validate...
# 11      {'BusinessParking': {'garage': False, 'validat...
# 12      {'BusinessParking': {'garage': False, 'validat...
# 13      {'BusinessAcceptsBitcoin': False, 'ByAppointme...
# 14      {'BusinessParking': {'garage': False, 'validat...
# 15      {'RestaurantsAttire': 'casual', 'Alcohol': 'no...
# 16      {'ByAppointmentOnly': True, 'BusinessAcceptsCr...
# 17                   {'BusinessAcceptsCreditCards': True}
# 18      {'BusinessParking': {'garage': False, 'validat...
# 19                                                     {}
# 20                   {'BusinessAcceptsCreditCards': True}
# 21      {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 22      {'HasTV': True, 'RestaurantsAttire': 'casual',...
# 23                            {'ByAppointmentOnly': True}
# 24                                                     {}
# 25      {'BusinessParking': {'garage': False, 'lot': F...
# 26                                  {'GoodForKids': True}
# 27      {'RestaurantsPriceRange2': 2, 'BusinessAccepts...
# 28      {'BusinessParking': {'garage': False, 'validat...
# 29      {'ByAppointmentOnly': False, 'BusinessAcceptsC...
# ...                                                   ...
# 156609                                                 {}
# 156610  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156611  {'BusinessParking': {'garage': False, 'validat...
# 156612  {'BusinessParking': {'garage': False, 'validat...
# 156613  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156614  {'BusinessParking': {'garage': False, 'validat...
# 156615  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156616                                                 {}
# 156617  {'RestaurantsPriceRange2': 1, 'GoodForKids': T...
# 156618  {'Ambience': {'romantic': False, 'upscale': Fa...
# 156619               {'BusinessAcceptsCreditCards': True}
# 156620  {'RestaurantsPriceRange2': 2, 'WiFi': 'free', ...
# 156621  {'HasTV': True, 'RestaurantsAttire': 'casual',...
# 156622  {'ByAppointmentOnly': True, 'BusinessAcceptsCr...
# 156623  {'BusinessAcceptsBitcoin': False, 'BusinessAcc...
# 156624  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156625  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156626  {'HasTV': False, 'RestaurantsAttire': 'casual'...
# 156627  {'RestaurantsPriceRange2': 2, 'BusinessAccepts...
# 156628                                                 {}
# 156629  {'BusinessParking': {'garage': False, 'validat...
# 156630                        {'ByAppointmentOnly': True}
# 156631  {'BusinessParking': {'garage': False, 'validat...
# 156632  {'HasTV': True, 'RestaurantsAttire': 'casual',...
# 156633  {'BusinessParking': {'garage': False, 'validat...
# 156634  {'BusinessParking': {'garage': False, 'validat...
# 156620                               [Coffee & Tea, Food]         Las Vegas
# 156621                            [Restaurants, Hot Dogs]          Goodyear
# 156622          [Orthopedists, Doctors, Health & Medical]         Henderson
# 156623  [Bail Bondsmen, Professional Services, Local S...         Las Vegas
# 156624                             [Restaurants, Mexican]          Sun City
# 156625                               [Pizza, Restaurants]         Charlotte
# 156626      [Restaurants, Delis, Sandwiches, Food Stands]        Pittsburgh
# 156627  [Furniture Reupholstery, Flooring, Home & Gard...          Glendale
# 156628  [Telecommunications, Mobile Phones, Shopping, ...          Glendale
# 156629  [Beauty & Spas, Health & Medical, Reflexology,...          Glendale
# 156630  [Massage, Chiropractors, Health & Medical, Bea...           Markham
# 156631  [Food, Taiwanese, Restaurants, Coffee & Tea, C...          Montréal
# 156632                             [Restaurants, Burgers]           Toronto
# 156633             [Day Spas, Beauty & Spas, Hair Salons]         Charlotte
# 156634  [Art Galleries, Flowers & Gifts, Event Plannin...           Toronto
# 156635                      [American (New), Restaurants]         Las Vegas
# 156636                          [Auto Repair, Automotive]             Tempe
# 156637                                [Zoos, Active Life]         Inverness
# 156638  [Fashion, Shopping, Food, Department Stores, M...         Henderson
#
#                                                     hours  is_open   latitude  \
# 0       {'Tuesday': '10:00-21:00', 'Monday': '10:00-21...        1  41.541716
# 1       {'Tuesday': '10:00-22:00', 'Monday': '10:00-22...        0  35.236870
# 2       {'Tuesday': '10:00-19:00', 'Monday': '10:00-19...        0  43.677126
# 3       {'Tuesday': '9:00-17:00', 'Thursday': '9:00-17...        1  33.565082
# 4                                                      {}        0  33.505928
# 5       {'Tuesday': '10:00-20:00', 'Monday': '10:00-20...        0  33.508068
# 6       {'Tuesday': '14:00-19:00', 'Thursday': '14:00-...        1  33.502848
# 7       {'Tuesday': '8:00-17:00', 'Monday': '8:00-17:0...        1  40.485939
# 8       {'Tuesday': '10:00-18:00', 'Monday': '10:00-18...        1  40.290498
# 9       {'Tuesday': '7:30-17:00', 'Thursday': '7:30-17...        1  33.324539
# 10                                                     {}        1  36.159098
# 11      {'Tuesday': '10:00-18:00', 'Monday': '10:00-18...        0  33.570421
# 12      {'Tuesday': '5:00-0:00', 'Monday': '5:00-0:00'...        1  33.377428
# 13      {'Tuesday': '8:00-17:00', 'Monday': '8:00-17:0...        1  33.431335
# 14      {'Tuesday': '11:00-0:00', 'Monday': '11:00-0:0...        1  35.135196
# 15      {'Tuesday': '11:30-22:00', 'Monday': '11:30-22...        1  35.355085
# 16      {'Tuesday': '7:00-19:00', 'Monday': '7:00-19:0...        1  33.413219
# 17      {'Tuesday': '8:30-18:00', 'Monday': '8:30-18:0...        1  41.501820
# 18      {'Monday': '9:00-20:00', 'Saturday': '9:00-20:...        1  41.509408
# 19      {'Tuesday': '10:00-19:00', 'Monday': '10:00-19...        1  36.040413
# 20      {'Tuesday': '8:00-18:00', 'Monday': '8:00-18:0...        1  35.089534
# 21      {'Tuesday': '8:00-12:00', 'Thursday': '8:00-12...        1  40.461350
# 22                                                     {}        1  43.639236
# 23                                                     {}        1  33.370202
# 24      {'Tuesday': '8:00-17:00', 'Monday': '8:00-17:0...        1  33.377892
# 25      {'Tuesday': '12:00-1:00', 'Monday': '12:00-1:0...        1  55.954486
# 26                                                     {}        1  43.663669
# 27      {'Tuesday': '12:00-21:00', 'Monday': '12:00-21...        1  45.515279
# 28      {'Tuesday': '9:00-21:00', 'Monday': '9:00-21:0...        1  40.460239
# 29      {'Tuesday': '10:00-20:00', 'Monday': '10:00-20...        1  33.623655
# ...                                                   ...      ...        ...
# 156609                                                 {}        1  33.424934
# 156610  {'Tuesday': '9:00-9:00', 'Monday': '9:00-9:00'...        1  36.150021
# 156611  {'Tuesday': '12:00-0:00', 'Monday': '12:00-0:0...        1  36.113961
# 156612  {'Tuesday': '9:00-19:00', 'Monday': '9:00-19:0...        1  33.638479
# 156613  {'Tuesday': '12:00-22:00', 'Monday': '12:00-22...        1  43.650741
# 156614  {'Tuesday': '10:00-18:00', 'Monday': '10:00-18...        1  45.477754
# 156615  {'Tuesday': '8:00-18:00', 'Monday': '8:00-18:0...        1  36.086867
# 156616  {'Tuesday': '9:00-17:00', 'Thursday': '9:00-17...        1  36.083392
# 156617                                                 {}        1  43.754927
# 156618  {'Tuesday': '11:00-22:00', 'Monday': '11:00-21...        1  45.520289
# 156619  {'Tuesday': '7:00-18:00', 'Thursday': '7:00-18...        1  33.600877
# 156620  {'Tuesday': '5:00-19:30', 'Monday': '5:00-19:3...        1  36.240136
# 156621                                                 {}        0  33.456435
# 156622  {'Tuesday': '8:00-17:00', 'Thursday': '8:00-17...        1  35.999473
# 156623  {'Tuesday': '0:00-0:00', 'Monday': '0:00-0:00'...        1  36.167682
# 156624  {'Tuesday': '11:00-20:00', 'Monday': '11:00-20...        1  33.600876
# 156625  {'Tuesday': '10:00-1:00', 'Monday': '10:00-1:0...        1  35.313384
# 156626  {'Thursday': '10:00-19:00', 'Saturday': '9:00-...        0  40.453845
# 156627  {'Tuesday': '10:00-21:00', 'Monday': '10:00-21...        0  33.637932
# 156628  {'Tuesday': '10:00-21:00', 'Monday': '10:00-21...        1  33.639791
# 156629  {'Tuesday': '10:00-21:00', 'Monday': '10:00-21...        1  33.637750
# 156630  {'Tuesday': '9:30-19:00', 'Monday': '9:30-19:0...        1  43.867263
# 156631  {'Tuesday': '11:00-0:00', 'Monday': '11:00-0:0...        0  45.492610
# 156632  {'Tuesday': '11:30-21:00', 'Monday': '11:30-21...        0  43.710603
# 156633  {'Tuesday': '9:00-20:00', 'Monday': '9:00-20:0...        1  35.035421
# 156634  {'Tuesday': '12:00-18:00', 'Thursday': '12:00-...        0  43.661834
# 156635                                                 {}        0  36.137112
# 156636                                                 {}        1  33.426949
# 156637                                                 {}        1  57.519612
# 156638                                                 {}        0  36.060708
#
#          longitude                                name  \
# 0       -81.493116                Richmond Town Square
# 1       -80.741976  South Florida Style Chicken & Ribs
# 2       -79.353285                    The Tea Emporium
# 3      -111.916400                            TRUmatch
# 13                                          85323            41    4.5    AZ
# 14                                          28105            21    2.0    NC
# 15                                          28164             3    3.0    NC
# 16                                          85210             3    3.5    AZ
# 17                                          44121            25    3.0    OH
# 18                  Goodrich Kirtland       44114           162    4.0    OH
# 19                          Southeast       89123             3    3.5    NV
# 20                                          28134            14    3.0    NC
# 21                         Bloomfield       15224            15    3.0    PA
# 22                 Meadowvale Village     L5W 0E6             6    2.5    ON
# 23                                          85234            33    5.0    AZ
# 24                                          85209             8    5.0    AZ
# 25                                        EH1 3AT            14    4.0   EDH
# 26              University of Toronto     M5S 3H3             8    4.0    ON
# 27                        Ville-Marie     H2X 3K4             3    4.0    QC
# 28                          Shadyside       15206            10    3.5    PA
# 29                                          85254            11    3.5    AZ
# ...                               ...         ...           ...    ...   ...
# 156609                                      85281            23    3.0    AZ
# 156610                                      89104           108    3.0    NV
# 156611                       Eastside       89121             3    5.0    NV
# 156612                                      85022           157    4.5    AZ
# 156613            Distillery District     M5A 3C4           570    3.5    ON
# 156614            Notre-Dame-de-Grâce     H3Z 1H3             4    3.5    QC
# 156615                      Southeast       89120             9    4.5    NV
# 156616                      Southeast       89120             4    5.0    NV
# 156617                                    M3H 2S4             3    2.0    ON
# 156618                    Ville-Marie     H2L 2H7            10    4.5    QC
# 156619                                      85022            15    4.0    AZ
# 156620                      Northwest       89129            22    4.0    NV
# 156621                                      85338            54    4.0    AZ
# 156622                         Anthem       89052            40    3.5    NV
# 156623                       Downtown       89101             5    5.0    NV
# 156624                                      85351            50    3.5    AZ
# 156625                University City       28262             9    2.0    NC
# 156626                 Strip District       15222             3    4.5    PA
# 156627                                      85308            18    1.5    AZ
# 156628                                      85308             3    1.0    AZ
# 156629                                      85308            12    5.0    AZ
# 156630                     Unionville     L3P 7M7             3    4.5    ON
# 156631                    Ville-Marie     H3H 1M3             8    3.0    QC
# 156632  Mount Pleasant and Davisville     M4P 2E7            22    3.0    ON
# 156633                     Ballantyne       28277            14    3.5    NC
# 156634                    Leslieville     M4M 1K7             4    5.0    ON
# 156635                       Eastside       89109            42    4.0    NV
# 156636                                      85281             3    3.5    AZ
# 156637                                    IV1 1XF             8    3.5   HLD
# 156638                                      89014            42    2.5    NV
#
#             rank
# 0        50024.5
# 1       125069.5
# 2        90951.5
# 3       144966.5
# 4        72584.5
# 5        27600.0
# 6        45979.0
# 7        52314.5
# 8        90951.5
# 9        83774.5
# 10       60673.0
# 11       90951.5
# 12       42540.0
# 13       23843.5
# 14       42540.0
# 15      144966.5
# 16      144966.5
# 17       36949.5
# 18        5007.0
# 19      144966.5
# 20       57577.5
# 21       54816.5
# 22       99726.0
# 23       29156.0
# 24       83774.5
# 25       57577.5
# 26       83774.5
# 27      144966.5
# 28       72584.5
# 29       68152.5
# ...          ...
# 156609   39587.0
# 156610    8389.0
# 156611  144966.5
# 156612    5226.5
# 156613     648.5
# 156614  125069.5
# 156615   77732.0
# 156616  125069.5
# 156617  144966.5
# 156618   72584.5
# 156619   54816.5
# 156620   41010.0
# 156621   18120.0
# 156622   24412.0
# 156623  110706.0
# 156624   19588.0
# 156625   77732.0
# 156626  144966.5
# 156627   47914.0
# 156628  144966.5
# 156629   64195.5
# 156630  144966.5
# 156631   83774.5
# 156632   41010.0
# 156633   57577.5
# 156634  125069.5
# 156635   23292.5
# 156636  144966.5
# 156637   83774.5
# 156638   23292.5
#
# [156639 rows x 16 columns]

# %%
mydf['rank'].corr(mydf['review_count'])
# Out:
# -0.38490690747557477

# %% [markdown]
# Now we have a general understanding of the popular locations, and relationship between review counts and stars, we then going to use SQL to calculate the propotion of individual ratings.

# %% [markdown]
# # Data Exploration and basis analysis  by PYMYSQL

# %%
conn = pymysql.connect('localhost','root','123456', db ='yelp_db')

# %%
cursor = conn.cursor()

# %%
sql = '''
        SELECT stars, (count(stars)*100/(select count(*) From review)) as score
        FROM review
        group by stars
        ;
    '''
cursor.execute(sql)
cursor.fetchall()
# Out:
# ((1, Decimal('13.5078')),
#  (2, Decimal('8.4949')),
#  (3, Decimal('12.0505')),
#  (4, Decimal('23.9784')),
#  (5, Decimal('41.9685')))

# %% [markdown]
# We found out that most of peopel gave 5-star reviews.

# %%
test_nei=pdSQL.read_sql("""
SELECT neighborhood, state, COUNT(DISTINCT name) as num_res, COUNT(review_count) AS count, (COUNT(DISTINCT name)/COUNT(review_count)) as ave_rew
FROM business 
WHERE neighborhood IS NOT NULL
AND neighborhood != " "
GROUP BY state, neighborhood
ORDER BY count
DESC LIMIT 20""", conn)
print (test_nei)
# Out:
#           neighborhood state  num_res  count  ave_rew
# 0             Westside    NV     3015   3237   0.9314
# 1            Southeast    NV     2770   3082   0.8988
# 2            The Strip    NV     2334   2626   0.8888
# 3        Spring Valley    NV     2225   2405   0.9252
# 4          Ville-Marie    QC     1992   2173   0.9167
# 5          Scarborough    ON     1578   1751   0.9012
# 6             Eastside    NV     1596   1714   0.9312
# 7             Downtown    NV     1582   1629   0.9711
# 8   Plateau-Mont-Royal    QC     1385   1433   0.9665
# 9        Downtown Core    ON     1250   1381   0.9051
# 10           Southwest    NV     1082   1187   0.9115
# 11           Etobicoke    ON     1076   1160   0.9276
# 12              Anthem    NV      964    992   0.9718
# 13           Northwest    NV      838    914   0.9168
# 14          Centennial    NV      803    871   0.9219
# 15           Summerlin    NV      748    789   0.9480
# 16           Chinatown    NV      769    783   0.9821
# 17            New Town   EDH      688    716   0.9609
# 18            Old Town   EDH      686    706   0.9717
# 19             Sunrise    NV      586    653   0.8974

# %% [markdown]
# In order to determin which neighborhood has the most competition, we ranked the review count of each neighborhood in the USA, and found that neighborhoods in NV has the most review counts and restaurants. All the neighborhoods are in Las Vegas. The average review counts look approximately similar to each other. Hence, it is fair to say that the reviews count is an accurate represenation of the popularity.

# %% [markdown]
# After knowing what location is more popular, we are going to see what type of business is more popular.

# %%
test_cat=pdSQL.read_sql("""
SELECT category, COUNT(*) AS count 
FROM category 
JOIN business ON category.business_id=business.id 
GROUP BY category 
ORDER BY count 
DESC LIMIT 10""", conn)
print (test_cat)
# Out:
#            category  count
# 0       Restaurants  51613
# 1          Shopping  24595
# 2              Food  23014
# 3     Beauty & Spas  15139
# 4     Home Services  13202
# 5  Health & Medical  12033
# 6         Nightlife  11364
# 7              Bars   9868
# 8        Automotive   9476
# 9    Local Services   9343

# %% [markdown]
# We also sorted the different categories, and found out that the majority of business in Yelp is restaurants. Hence, we are going to continue our study below only on restaurants.
# One business can have multiple catigories, which is the reason why there is restaurants and food existing at the same time.

# %%
test_hour=pdSQL.read_sql("""
SELECT hours, count(review_count) AS sum_rew
FROM hours 
JOIN business ON hours.business_id=business.id  
GROUP BY hours
ORDER BY sum_rew DESC 
LIMIT 10""", conn)
print (test_hour)
# Out:
#                   hours  sum_rew
# 0      Sunday|0:00-0:00     6207
# 1    Saturday|0:00-0:00     5855
# 2   Wednesday|0:00-0:00     5613
# 3    Thursday|0:00-0:00     5613
# 4     Tuesday|0:00-0:00     5604
# 5      Monday|0:00-0:00     5602
# 6      Friday|0:00-0:00     5600
# 7     Monday|8:00-17:00     4694
# 8    Tuesday|8:00-17:00     4690
# 9  Wednesday|8:00-17:00     4688

# %% [markdown]
# Based on the analysis above, businesses with longer hours tend to get more reviews. For the resturants open 24/7, it is more likely it will get more traffic.

# %% [markdown]
# # Import review.json data

# %%
lines = open('/Users/macbookair/Downloads/dataset 2/review.json').readlines()
reviews = []
for line in lines:
    reviews.append(json.loads(line))
# reviewsstr=''.join(str(e) for e in lines)
# reviews = json.loads(reviewsstr)
print(reviews[0])
# Out:
# {'text': 'My girlfriend and I stayed here for 3 nights and loved it. The location of this hotel and very decent price makes this an amazing deal. When you walk out the front door Scott Monument and Princes street are right in front of you, Edinburgh Castle and the Royal Mile is a 2 minute walk via a close right around the corner, and there are so many hidden gems nearby including Calton Hill and the newly opened Arches that made this location incredible.\n\nThe hotel itself was also very nice with a reasonably priced bar, very considerate staff, and small but comfortable rooms with excellent bathrooms and showers. Only two minor complaints are no telephones in room for room service (not a huge deal for us) and no AC in the room, but they have huge windows which can be fully opened. The staff were incredible though, letting us borrow umbrellas for the rain, giving us maps and directions, and also when we had lost our only UK adapter for charging our phones gave us a very fancy one for free.\n\nI would highly recommend this hotel to friends, and when I return to Edinburgh (which I most definitely will) I will be staying here without any hesitation.', 'review_id': 'VfBHSwC5Vz_pbFluy07i9Q', 'date': '2016-07-12', 'business_id': 'uYHaNptLzDLoV_JZ_MuzUA', 'useful': 0, 'stars': 5, 'funny': 0, 'cool': 0, 'user_id': 'cjpdDjZyprfyDG3RlkVG3w'}

# %% [markdown]
# ### random sample selected

# %% [markdown]
# Randomly select 50000 reviews to analysis, becasue the amount should be enough to get a conclusion and won't kill the laptop due to data size.

# %%
sample_reviews = [ reviews[i] for i in sorted(random.sample(range(len(reviews)), 50000)) ]

# %% [markdown]
# Transform capital characters.

# %%
words = []
for i in range(len(sample_reviews)):
    words.append(sample_reviews[i]['text'].lower())

# %% [markdown]
# Count the number of words from the reviews.

# %%
popular_words= {}
for i in range(len(words)):
    for buzz in words[i].split():
        if buzz not in popular_words:
            popular_words[buzz] = 1
        else:
            popular_words[buzz] +=1

# %% [markdown]
# Remove punctuations

# %%
import fileinput

wordss = [',', '.', '!', ';', '!!', '!!!!!','"', '"50/50', '"\'this', '!"', '",', '".', '!!!', '!!!!', '!!!!!!', '!!.', '!)', '!?']

for i in wordss:
    if i in popular_words:
        popular_words.pop(i, None)

# %% [markdown]
# ### Analysis popular features of restaurants from reivews

# %%
dictfilt = lambda x, y: dict([ (i,x[i]) for i in x if i in set(y) ])

# %%
popwords = ['food', 'service', 'time', 'staff', 'friendly', 'location', 'price', 'sauce', 'atmosphere','parking','music']

# %%
pop_words = dictfilt(popular_words, popwords)

# %%
pop_words_sorted_keys = sorted(pop_words, key=pop_words.get, reverse=True)
for r in pop_words_sorted_keys:
    print (r, pop_words[r])
# Out:
# food 18457
# time 12413
# service 12390
# staff 6357
# friendly 4866
# location 3043
# price 2942
# sauce 2808
# atmosphere 1715
# parking 1582
# music 1196

# %%
plt.bar(list(pop_words.keys()), pop_words.values(), color='g')
plt.show()

# %% [markdown]
# ![Screen%20Shot%202017-12-08%20at%2020.12.31.png](attachment:Screen%20Shot%202017-12-08%20at%2020.12.31.png)

# %% [markdown]
# The rank of key words in the list indicates features of restaurants. The list shows the different level of importance of the identities by the number counted from reviews. The key words are searched from Google to classify the restaurants. Hence, the "pop_words" dictionary, showing the counts of the words, can be applied by businesses to identify what is appealing to customers. In other words, hosts get clue about where to focus on or to emphasis in order to attract customers.
#
# Accordingly, the food is undoubtly the most important element, following by service and time, around one fourth in 50000 reviews. Counts of the three words are significantly larger that the others, so logically, all the businesses should pay more attention to promote themselves.

# %% [markdown]
# ### Analysis popular foods types from reviews

# %%
popfood = ['chicken', 'pizza', 'cheese', 'salad', 'drink', 'burger', 'soup', 'coffee', 'fries','thai', 'tacos', 'steak','sandwich','pork', 'bread','buffet']

# %%
pop_food = dictfilt(popular_words, popfood)

# %%
pop_food_sorted_keys = sorted(pop_food, key=pop_food.get, reverse=True)
for r in pop_food_sorted_keys:
    print (r, pop_food[r])
# Out:
# chicken 5576
# pizza 3519
# cheese 3075
# salad 2682
# drink 2333
# coffee 2220
# burger 2220
# fries 2056
# steak 1795
# sandwich 1775
# pork 1734
# bread 1706
# soup 1417
# thai 1162
# tacos 1040
# buffet 1006

# %%
plt.bar(list(pop_food.keys()), pop_food.values(), color='g')
plt.show()

# %% [markdown]
# ![Screen%20Shot%202017-12-08%20at%2020.20.35.png](attachment:Screen%20Shot%202017-12-08%20at%2020.20.35.png)

# %% [markdown]
# From the rank of the key words of foods, it is shown that chicken is more poppular than pork and steak. Besides, when it comes to food types, pizza looks appear more often than others. Tacos is absolutely mentioned less times, almost only one third.

# %% [markdown]
# ## Conclusion
# For people who are interested in opening up a new resturant in the US, locating in Las Vegas will bring you the most traffic.
# For food choices, if you decide to serve chicken, it will bring most attention.

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# # Explore data

# %%
opioid2014 = pd.read_csv('Medicare_Part_D_Opioid_Prescriber_Summary_File_2014.csv')

# %%
print(opioid2014.shape)
# Out:
# (1072997, 9)

# %%
opioid2014.head(5)
# Out:
#           NPI NPPES Provider Last/Org Name NPPES Provider First Name  \
# 0  1518048750                      A VILES                      OMAR
# 1  1952310666                    A'BODJEDI                    ENENGE
# 2  1467482471                          AAB                     BARRY
# 3  1801093968                       AABERG                   MELANIE
# 4  1588763981                       AABERG                    RANDAL
#
#    NPPES Provider Zip Code NPPES Provider State Specialty Description  \
# 0                  11501.0                   NY    Pediatric Medicine
# 1                   6902.0                   CT            Psychiatry
# 2                  45895.0                   OH               Dentist
# 3                  48183.0                   MI    Emergency Medicine
# 4                  96819.0                   HI               Urology
#
#    Total Claim Count  Opioid Claim Count Opioid Prescribing Rate
# ...

# %%
opioid2014.isnull().sum()
# Out:
# NPI                                  0
# NPPES Provider Last/Org Name        25
# NPPES Provider First Name           39
# NPPES Provider Zip Code             66
# NPPES Provider State                 0
# Specialty Description                0
# Total Claim Count                    0
# Opioid Claim Count              318938
# Opioid Prescribing Rate         318938
# dtype: int64

# %% [markdown]
# def get_rid_of_nulls(value):
#     if pd.isnull(value):
#         return '00000'
#     else:
#         return value

# %% [markdown]
# opioid2014['NPPES Provider Zip Code'] = opioid2014['NPPES Provider Zip Code'].apply(get_rid_of_nulls)

# %% [markdown]
# opioid2014.isnull().sum()

# %% [markdown]
# opioid2014['NPPES Provider Zip Code'] = pd.Series(["{:05d}".format(int(val)) for val in opioid2014['NPPES Provider Zip Code']], index = opioid.index)

# %%
opioid2014.head(5)
# Out:
#           NPI NPPES Provider Last/Org Name NPPES Provider First Name  \
# 0  1518048750                      A VILES                      OMAR
# 1  1952310666                    A'BODJEDI                    ENENGE
# 2  1467482471                          AAB                     BARRY
# 3  1801093968                       AABERG                   MELANIE
# 4  1588763981                       AABERG                    RANDAL
#
#    NPPES Provider Zip Code NPPES Provider State Specialty Description  \
# 0                  11501.0                   NY    Pediatric Medicine
# 1                   6902.0                   CT            Psychiatry
# 2                  45895.0                   OH               Dentist
# 3                  48183.0                   MI    Emergency Medicine
# 4                  96819.0                   HI               Urology
#
#    Total Claim Count  Opioid Claim Count Opioid Prescribing Rate
# ...

# %%
opioid2013 = pd.read_csv('Medicare_Part_D_Opioid_Prescriber_Summary_File_2013.csv')

# %%
opioid2015 = pd.read_csv('Medicare_Part_D_Opioid_Prescriber_Summary_File_2015.csv')

# %%
print(opioid2013.shape)
# Out:
# (1049326, 9)

# %%
print(opioid2015.shape)
# Out:
# (1102268, 11)

# %%
opioid2013.head(5)
# Out:
#           NPI                      NPPES Provider Last Name  \
# 0  1447268107                         10 PARK PHARMACY INC.
# 1  1174856348  101 FAMILY MEDICAL GROUP,A PROFESSIONAL CORP
# 2  1720181522              154ST STREET MEDICAL PLAZA, INC.
# 3  1821285826                     21ST CENTURY ONCOLOGY LLC
# 4  1457520132                         3 SUNS INVESTMENT INC
#
#   NPPES Provider First Name  NPPES Provider ZIP Code NPPES Provider State  \
# 0                       NaN                  10016.0                   NY
# 1                       NaN                  91303.0                   CA
# 2                       NaN                  33014.0                   FL
# 3                       NaN                  33180.0                   FL
# 4                       NaN                  98225.0                   WA
#
#   Specialty Description Total Claim Count Opioid Claim Count  \
# 0            Pharmacist                18                  0
# ...

# %%
opioid2014.head(5)
# Out:
#           NPI NPPES Provider Last/Org Name NPPES Provider First Name  \
# 0  1518048750                      A VILES                      OMAR
# 1  1952310666                    A'BODJEDI                    ENENGE
# 2  1467482471                          AAB                     BARRY
# 3  1801093968                       AABERG                   MELANIE
# 4  1588763981                       AABERG                    RANDAL
#
#    NPPES Provider Zip Code NPPES Provider State Specialty Description  \
# 0                  11501.0                   NY    Pediatric Medicine
# 1                   6902.0                   CT            Psychiatry
# 2                  45895.0                   OH               Dentist
# 3                  48183.0                   MI    Emergency Medicine
# 4                  96819.0                   HI               Urology
#
#    Total Claim Count  Opioid Claim Count Opioid Prescribing Rate
# ...

# %%
opioid2015.head(5)
# Out:
#           NPI NPPES Provider Last Name NPPES Provider First Name  \
# 0  1003000126                ENKESHAFI                   ARDALAN
# 1  1003000142                   KHALIL                    RASHID
# 2  1003000167                  ESCOBAR                     JULIO
# 3  1003000175            REYES-VASQUEZ                   BELINDA
# 4  1003000282                BLAKEMORE                     ROSIE
#
#    NPPES Provider ZIP Code NPPES Provider State Specialty Description  \
# 0                  21502.0                   MD     Internal Medicine
# 1                  43623.0                   OH        Anesthesiology
# 2                  89403.0                   NV               Dentist
# 3                  91744.0                   CA               Dentist
# 4                  37243.0                   TN    Nurse Practitioner
#
#   Total Claim Count Opioid Claim Count Opioid Prescribing Rate  \
# 0               825                 38           4.6060606061%
# ...

# %%
opioid2015 = opioid2015.drop(['Extended-Release Opioid Claims', 'Extended-Release Opioid Prescribing Rate'], axis=1)

# %%
opioid2015.head(5)
# Out:
#           NPI NPPES Provider Last Name NPPES Provider First Name  \
# 0  1003000126                ENKESHAFI                   ARDALAN
# 1  1003000142                   KHALIL                    RASHID
# 2  1003000167                  ESCOBAR                     JULIO
# 3  1003000175            REYES-VASQUEZ                   BELINDA
# 4  1003000282                BLAKEMORE                     ROSIE
#
#    NPPES Provider ZIP Code NPPES Provider State Specialty Description  \
# 0                  21502.0                   MD     Internal Medicine
# 1                  43623.0                   OH        Anesthesiology
# 2                  89403.0                   NV               Dentist
# 3                  91744.0                   CA               Dentist
# 4                  37243.0                   TN    Nurse Practitioner
#
#   Total Claim Count Opioid Claim Count Opioid Prescribing Rate
# 0               825                 38           4.6060606061%
# ...

# %%
print(opioid2015.shape)
# Out:
# (1102268, 9)

# %% [markdown]
# ## File Merge

# %%
opioid2014 = opioid2014.rename(columns={'NPPES Provider Last/Org Name': 'NPPES Provider Last Name', 'NPPES Provider Zip Code': 'NPPES Provider ZIP Code'})

# %%
dfs = [opioid2013, opioid2014, opioid2015]

# %%
opioid = pd.concat(dfs)

# %%
print(opioid.shape)
# Out:
# (3224591, 9)

# %%
opioid.head(5)
# Out:
#           NPI                      NPPES Provider Last Name  \
# 0  1447268107                         10 PARK PHARMACY INC.
# 1  1174856348  101 FAMILY MEDICAL GROUP,A PROFESSIONAL CORP
# 2  1720181522              154ST STREET MEDICAL PLAZA, INC.
# 3  1821285826                     21ST CENTURY ONCOLOGY LLC
# 4  1457520132                         3 SUNS INVESTMENT INC
#
#   NPPES Provider First Name  NPPES Provider ZIP Code NPPES Provider State  \
# 0                       NaN                  10016.0                   NY
# 1                       NaN                  91303.0                   CA
# 2                       NaN                  33014.0                   FL
# 3                       NaN                  33180.0                   FL
# 4                       NaN                  98225.0                   WA
#
#   Specialty Description Total Claim Count Opioid Claim Count  \
# 0            Pharmacist                18                  0
# ...

# %%
opioid.isnull().sum()
# Out:
# NPI                               0
# NPPES Provider Last Name         78
# NPPES Provider First Name      6837
# NPPES Provider ZIP Code         193
# NPPES Provider State              0
# Specialty Description             0
# Total Claim Count                 0
# Opioid Claim Count           951792
# Opioid Prescribing Rate      951792
# dtype: int64

# %%
def get_rid_of_nulls(value):
    if pd.isnull(value):
        return '00000'
    else:
        return value

# %%
opioid['NPPES Provider ZIP Code'] = opioid['NPPES Provider ZIP Code'].apply(get_rid_of_nulls)

# %%
def get_rid_of_nulls_name(value):
    if pd.isnull(value):
        return 'AAAA'
    else:
        return value

# %%
opioid['NPPES Provider Last Name'] = opioid['NPPES Provider Last Name'].apply(get_rid_of_nulls_name)

# %%
opioid['NPPES Provider First Name'] = opioid['NPPES Provider First Name'].apply(get_rid_of_nulls_name)

# %%
def get_rid_of_nulls_num(value):
    if pd.isnull(value):
        return '0'
    else:
        return value

# %%
opioid['Opioid Claim Count'] = opioid['Opioid Claim Count'].apply(get_rid_of_nulls_num)

# %%
opioid['Opioid Prescribing Rate'] = opioid['Opioid Prescribing Rate'].apply(get_rid_of_nulls_num)

# %%
opioid.isnull().sum()
# Out:
# NPI                          0
# NPPES Provider Last Name     0
# NPPES Provider First Name    0
# NPPES Provider ZIP Code      0
# NPPES Provider State         0
# Specialty Description        0
# Total Claim Count            0
# Opioid Claim Count           0
# Opioid Prescribing Rate      0
# dtype: int64

# %% [markdown]
# ### Zip Code col modificaion

# %%
opioid['NPPES Provider ZIP Code'] = pd.Series(["{:05d}".format(int(val)) for val in opioid['NPPES Provider ZIP Code']], index = opioid.index)

# %%
opioid.head(5)
# Out:
#           NPI                      NPPES Provider Last Name  \
# 0  1447268107                         10 PARK PHARMACY INC.
# 1  1174856348  101 FAMILY MEDICAL GROUP,A PROFESSIONAL CORP
# 2  1720181522              154ST STREET MEDICAL PLAZA, INC.
# 3  1821285826                     21ST CENTURY ONCOLOGY LLC
# 4  1457520132                         3 SUNS INVESTMENT INC
#
#   NPPES Provider First Name NPPES Provider ZIP Code NPPES Provider State  \
# 0                      AAAA                   10016                   NY
# 1                      AAAA                   91303                   CA
# 2                      AAAA                   33014                   FL
# 3                      AAAA                   33180                   FL
# 4                      AAAA                   98225                   WA
#
#   Specialty Description Total Claim Count Opioid Claim Count  \
# 0            Pharmacist                18                  0
# ...

# %% [markdown]
# # GDP Vs Opioid Claim

# %%
opioid.to_csv("opioid_merged.csv")

# %%
import plotly.plotly as py

# %%
GDP_States = pd.read_csv("GDP_States.csv")

# %%
GDP_States.head(5)
# Out:
#    Fips           Area   1997   1998   1999   2000   2001   2002   2003  \
# 0     0  United States  40781  42045  43513  44714  44689  45068  45831
# 1  1000        Alabama  31398  32164  33106  33284  33312  34068  34855
# 2  2000         Alaska  61797  59504  58609  57184  58547  60101  59008
# 3  4000        Arizona  34434  36311  38300  39185  39170  39323  40769
# 4  5000       Arkansas  30435  30513  31877  31834  31685  32514  33678
#
#     2004  ...     2007   2008   2009   2010   2011   2012   2013   2014  \
# 0  47010  ...    49126  48401  46680  47287  47595  48173  48538  49339
# 1  36702  ...    37522  36976  35376  35913  36201  36425  36660  36455
# 2  60137  ...    67228  67527  72204  69564  70573  73478  69700  67188
# 3  41063  ...    44168  41800  38232  37935  38257  38559  38303  38450
# 4  34936  ...    35205  34957  33837  34671  35146  34965  35865  36274
#
#     2015   2016
# 0  50323  50708
# 1  36911  37402
# 2  67302  63317
# 3  38647  38985
# ...

# %%
GDP_States = GDP_States.drop(0)

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
GDP_States['NPPES Provider State'] = GDP_States['Area'].replace(us_state_abbrev, regex=True)

# %%
GDP_States.head(5)
# Out:
#    Fips        Area   1997   1998   1999   2000   2001   2002   2003   2004  \
# 1  1000     Alabama  31398  32164  33106  33284  33312  34068  34855  36702
# 2  2000      Alaska  61797  59504  58609  57184  58547  60101  59008  60137
# 3  4000     Arizona  34434  36311  38300  39185  39170  39323  40769  41063
# 4  5000    Arkansas  30435  30513  31877  31834  31685  32514  33678  34936
# 5  6000  California  41345  43098  45541  48223  47216  47880  49501  51520
#
#            ...            2008   2009   2010   2011   2012   2013   2014  \
# 1          ...           36976  35376  35913  36201  36425  36660  36455
# 2          ...           67527  72204  69564  70573  73478  69700  67188
# 3          ...           41800  38232  37935  38257  38559  38303  38450
# 4          ...           34957  33837  34671  35146  34965  35865  36274
# 5          ...           54454  51733  51871  52099  52974  53855  55598
#
#     2015   2016  NPPES Provider State
# ...

# %%
a = ["AK","AL","AR","AZ","CA","CO","CT","DE","FL","GA","HI","IA","ID", "IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND","NE","NH","NJ","NM","NV","NY","OH","OK","OR","PA","RI","SC","SD","TN","TX","UT","VA","VT","WA","WI","WV","WY"]

# %%
GDP_States = GDP_States[~GDP_States['NPPES Provider State'].isin(a)== False]

# %%
print(GDP_States.shape)
# Out:
# (50, 23)

# %%
GDP_States.head(5)
# Out:
#    Fips        Area   1997   1998   1999   2000   2001   2002   2003   2004  \
# 1  1000     Alabama  31398  32164  33106  33284  33312  34068  34855  36702
# 2  2000      Alaska  61797  59504  58609  57184  58547  60101  59008  60137
# 3  4000     Arizona  34434  36311  38300  39185  39170  39323  40769  41063
# 4  5000    Arkansas  30435  30513  31877  31834  31685  32514  33678  34936
# 5  6000  California  41345  43098  45541  48223  47216  47880  49501  51520
#
#            ...            2008   2009   2010   2011   2012   2013   2014  \
# 1          ...           36976  35376  35913  36201  36425  36660  36455
# 2          ...           67527  72204  69564  70573  73478  69700  67188
# 3          ...           41800  38232  37935  38257  38559  38303  38450
# 4          ...           34957  33837  34671  35146  34965  35865  36274
# 5          ...           54454  51733  51871  52099  52974  53855  55598
#
#     2015   2016  NPPES Provider State
# ...

# %%
opioid2013 = opioid2013[~opioid2013['NPPES Provider State'].isin(a)== False]

# %%
claim_count_2013 = opioid2013.groupby('NPPES Provider State', as_index=False).count()

# %%
print(claim_count_2013.shape)
# Out:
# (50, 9)

# %%
claim_count_2013.head(5)
# Out:
#   NPPES Provider State     NPI  NPPES Provider Last Name  \
# 0                   AK    2275                      2275
# 1                   AL   12820                     12820
# 2                   AR    7909                      7908
# 3                   AZ   20542                     20542
# 4                   CA  109571                    109564
#
#    NPPES Provider First Name  NPPES Provider ZIP Code  Specialty Description  \
# 0                       2269                     2275                   2275
# 1                      12752                    12820                  12820
# 2                       7845                     7909                   7909
# 3                      20467                    20542                  20542
# 4                     108141                   109571                 109571
#
#    Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate
# 0               2275                1542                     1542
# ...

# %%
claim_count_2013.isnull().sum()
# Out:
# NPPES Provider State         0
# NPI                          0
# NPPES Provider Last Name     0
# NPPES Provider First Name    0
# NPPES Provider ZIP Code      0
# Specialty Description        0
# Total Claim Count            0
# Opioid Claim Count           0
# Opioid Prescribing Rate      0
# dtype: int64

# %%
opioid2014 = opioid2014[~opioid2014['NPPES Provider State'].isin(a)== False]

# %%
claim_count_2014 = opioid2014.groupby('NPPES Provider State', as_index=False).count()

# %%
opioid2015 = opioid2015[~opioid2015['NPPES Provider State'].isin(a)== False]

# %%
claim_count_2015 = opioid2015.groupby('NPPES Provider State', as_index=False).count()

# %%
opioid_GDP_2013 = pd.merge(claim_count_2013, GDP_States, on=['NPPES Provider State'])

# %%
opioid_GDP_2013.head(5)
# Out:
#   NPPES Provider State     NPI  NPPES Provider Last Name  \
# 0                   AK    2275                      2275
# 1                   AL   12820                     12820
# 2                   AR    7909                      7908
# 3                   AZ   20542                     20542
# 4                   CA  109571                    109564
#
#    NPPES Provider First Name  NPPES Provider ZIP Code  Specialty Description  \
# 0                       2269                     2275                   2275
# 1                      12752                    12820                  12820
# 2                       7845                     7909                   7909
# 3                      20467                    20542                  20542
# 4                     108141                   109571                 109571
#
#    Total Claim Count  Opioid Claim Count  Opioid Prescribing Rate  Fips  \
# 0               2275                1542                     1542  2000
# ...

# %%
opioid_GDP_2013.isnull().sum()
# Out:
# NPPES Provider State         0
# NPI                          0
# NPPES Provider Last Name     0
# NPPES Provider First Name    0
# NPPES Provider ZIP Code      0
# Specialty Description        0
# Total Claim Count            0
# Opioid Claim Count           0
# Opioid Prescribing Rate      0
# Fips                         0
# Area                         0
# 1997                         0
# 1998                         0
# 1999                         0
# 2000                         0
# 2001                         0
# 2002                         0
# 2003                         0
# 2004                         0
# 2005                         0
# 2006                         0
# 2007                         0
# 2008                         0
# 2009                         0
# 2010                         0
# 2011                         0
# 2012                         0
# 2013                         0
# 2014                         0
# 2015                         0
# ...

# %%
opioid_GDP_2014 = pd.merge(claim_count_2014, GDP_States, on=['NPPES Provider State'])

# %%
opioid_GDP_2015 = pd.merge(claim_count_2015, GDP_States, on=['NPPES Provider State'])

# %%
opioid_GDP_2013['Opioid Claim Count'].corr(opioid_GDP_2013['2013'])
# Out:
# 0.16370948943268293

# %%
opioid_GDP_2013['Opioid Claim Count'].corr(opioid_GDP_2013['Total Claim Count'])
# Out:
# 0.9993074738489837

# %%
opioid_GDP_2014['Opioid Claim Count'].corr(opioid_GDP_2014['2014'])
# Out:
# 0.17706642361053782

# %%
opioid_GDP_2014['Opioid Claim Count'].corr(opioid_GDP_2014['Total Claim Count'])
# Out:
# 0.9995339728019709

# %%
opioid_GDP_2015['Opioid Claim Count'].corr(opioid_GDP_2015['2015'])
# Out:
# 0.1991705388577177

# %%
opioid_GDP_2015['Opioid Claim Count'].corr(opioid_GDP_2015['Total Claim Count'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2ad47d67f46d> in <module>()
# ----> 1 opioid_GDP_2015['Opioid Claim Count'].corr(opioid_GDP_2015['Total Claim Count'])
#
# NameError: name 'opioid_GDP_2015' is not defined

# %% [markdown]
# ## NPPES

# %% [markdown]
# from pyspark import SparkContext
#
# from pyspark.sql import HiveContext, SQLContext, Row
# from pyspark.sql.types import *
# from datetime import datetime
# from pyspark.sql.functions import col, date_sub, log, mean, to_date, udf, unix_timestamp
# from pyspark.sql.window import Window
# from pyspark.sql import DataFrame

# %% [markdown]
# sc =SparkContext()
# sc.setLogLevel("DEBUG")
# sqlContext = SQLContext(sc)

# %% [markdown]
# opioid = sqlContext.read.format('com.databricks.spark.csv').option('delimiter', '\t').load('https://s3.amazonaws.com/aws-logs-233261414186-us-east-1/npidata_pfile.csv')

# %% [markdown]
# from pyspark.sql import SQLContext
# from pyspark.sql.types import *
# sqlContext = SQLContext(sc)

# %% [markdown]
# from pyspark import SparkContext,SparkConf
# conf=SparkConf().setAppName('Spark_Example_Python')
# sc=SparkContext(conf=conf)
# dataRDD=sc.textFile("/user/amit0900/spark_ex")
# for i in dataRDD.collect():
#     print(i)

# %%
from pyspark import SparkContext

# %% [markdown]
# from pyspark.sql import SparkSession

# %% [markdown]
# from pyspark.sql import Row

# %% [markdown]
# df =spark.read.csv("npidata_pfile.csv")

# %% [markdown]
# def get_first_and_last(filename):
#     #rdd variable holds the content of file(it's distributed)
#     rdd = spark.read.csv(filename, header=True, mode="DROPMALFORMED").rdd
#
#     #Here filename holds abs path. Feel free to substring as per your needs
#     return Row(filename, rdd.first, rdd.take(rdd.count()).last())

# %% [markdown]
# spark = SparkSession.builder.appName("Read CSVs").config("spark.some.config.option", "some-value").getOrCreate()
#
# filesList = spark.sparkContext.wholeTextFiles("npidata_pfile.csv").map(lambda x: x[0]).collect()
#
# #output array
# records = filesList.map(get_first_and_last)
#
# for record in records:
#     print(record)

# %%
import pandas as pd

# %%
mpd =pd.read_csv("mpd_opioid_prescriber_summary_2013_2015_enriched_v002.csv", sep='|', engine='python')

# %%
mpd.head(5)
# Out:
#           NPI Provider_Last_Name Provider_First_Name           Specialty  \
# 0  1194722678            SCHIMKE              LEANNE  Nurse Practitioner
# 1  1790782282             WALKER            VICTORIA     Family Practice
# 2  1861499352             BASORA              MANUEL     Family Practice
# 3  1942207436           TOMPKINS                KENT     Family Practice
# 4  1194727321              PARSA             KHOSROW   Internal Medicine
#
#    Extended_Release_Opioid_Claims_2015  Total_Claim_Count_2015  \
# 0                                    0                    1897
# 1                                    0                     166
# 2                                    0                    3568
# 3                                   53                   14626
# 4                                    0                      28
#
#    Opioid_Claim_Count_2015  Total_Claim_Count_2014  Opioid_Claim_Count_2014  \
# ...

# %%
print(mpd.shape)
# Out:
# (1102268, 37)

# %%
mpd.isnull().sum()
# Out:
# NPI                                          0
# Provider_Last_Name                          26
# Provider_First_Name                         34
# Specialty                                    0
# Extended_Release_Opioid_Claims_2015          0
# Total_Claim_Count_2015                       0
# Opioid_Claim_Count_2015                      0
# Total_Claim_Count_2014                       0
# Opioid_Claim_Count_2014                      0
# Total_Claim_Count_2013                       0
# Opioid_Claim_Count_2013                      0
# Entity_Type_Code                          7688
# Provider_Credential_Text                 56046
# Practice_Address_Line1                    7688
# Practice_Address_Line2                  666328
# Practice_Address_City                     7688
# Practice_Address_State                    7688
# Practice_Address_Zip                      7689
# Practice_Address_Country                  7688
# Enumeration_Date                             0
# ...

# %%
mpd = mpd.drop(mpd.columns[[12, 14, 20]], axis=1)

# %%
mpd.head(5)
# Out:
#           NPI Provider_Last_Name Provider_First_Name           Specialty  \
# 0  1194722678            SCHIMKE              LEANNE  Nurse Practitioner
# 1  1790782282             WALKER            VICTORIA     Family Practice
# 2  1861499352             BASORA              MANUEL     Family Practice
# 3  1942207436           TOMPKINS                KENT     Family Practice
# 4  1194727321              PARSA             KHOSROW   Internal Medicine
#
#    Extended_Release_Opioid_Claims_2015  Total_Claim_Count_2015  \
# 0                                    0                    1897
# 1                                    0                     166
# 2                                    0                    3568
# 3                                   53                   14626
# 4                                    0                      28
#
#    Opioid_Claim_Count_2015  Total_Claim_Count_2014  Opioid_Claim_Count_2014  \
# ...

# %%
print(mpd.shape)
# Out:
# (1102268, 34)

# %%
mpd.isnull().sum()
# Out:
# NPI                                          0
# Provider_Last_Name                          26
# Provider_First_Name                         34
# Specialty                                    0
# Extended_Release_Opioid_Claims_2015          0
# Total_Claim_Count_2015                       0
# Opioid_Claim_Count_2015                      0
# Total_Claim_Count_2014                       0
# Opioid_Claim_Count_2014                      0
# Total_Claim_Count_2013                       0
# Opioid_Claim_Count_2013                      0
# Entity_Type_Code                          7688
# Practice_Address_Line1                    7688
# Practice_Address_City                     7688
# Practice_Address_State                    7688
# Practice_Address_Zip                      7689
# Practice_Address_Country                  7688
# Enumeration_Date                             0
# Deactivation_Reason_Code               1102268
# Reactivation_Date                            0
# ...

# %%
def get_rid_of_nulls_num(value):
    if pd.isnull(value):
        return '0'
    else:
        return value

# %%
mpd['opioid_rate_2014'] = mpd['opioid_rate_2014'].apply(get_rid_of_nulls_num)
mpd['opioid_rate_2013'] = mpd['opioid_rate_2013'].apply(get_rid_of_nulls_num)
mpd['opioid_rate_pct_change_1yr'] = mpd['opioid_rate_pct_change_1yr'].apply(get_rid_of_nulls_num)
mpd['opioid_rate_pct_change_2yr'] = mpd['opioid_rate_pct_change_2yr'].apply(get_rid_of_nulls_num)

# %%
def get_rid_of_nulls_Deactivation(value):
    if value==0:
        return 'OT'
    else:
        return value

# %%
mpd['Deactivation_Reason_Code'] = mpd['Deactivation_Reason_Code'].apply(get_rid_of_nulls_Deactivation)

# %%
mpd = mpd.drop(mpd.columns[[32]], axis=1)

# %%
mpd = mpd.dropna()

# %%
print(mpd.shape)
# Out:
# (1094519, 34)

# %%
mpd.isnull().sum()
# Out:
# NPI                                    0
# Provider_Last_Name                     0
# Provider_First_Name                    0
# Specialty                              0
# Extended_Release_Opioid_Claims_2015    0
# Total_Claim_Count_2015                 0
# Opioid_Claim_Count_2015                0
# Total_Claim_Count_2014                 0
# Opioid_Claim_Count_2014                0
# Total_Claim_Count_2013                 0
# Opioid_Claim_Count_2013                0
# Entity_Type_Code                       0
# Practice_Address_Line1                 0
# Practice_Address_City                  0
# Practice_Address_State                 0
# Practice_Address_Zip                   0
# Practice_Address_Country               0
# Enumeration_Date                       0
# Deactivation_Reason_Code               0
# Reactivation_Date                      0
# Gender_Code                            0
# Is_Sole_Proprietor                     0
# opioid_rate_2015                       0
# ...

# %%
mpd.to_csv('mpd_wrangled.csv')

# %% [markdown]
# ### Prescriber_Random Forest Analysis

# %%
# imports
import h2o 
import numpy as np
import pandas as pd
from h2o.estimators.gbm import H2OGradientBoostingEstimator 
from h2o.estimators.random_forest import H2ORandomForestEstimator
from h2o.grid.grid_search import H2OGridSearch

# %%
# display matplotlib graphics in notebook
# %matplotlib inline

# %%
# start and connect to h2o server
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: java version "1.8.0_111"; Java(TM) SE Runtime Environment (build 1.8.0_111-b14); Java HotSpot(TM) 64-Bit Server VM (build 25.111-b14, mixed mode)
#   Starting server from /anaconda/lib/python3.5/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/qw/3c6hzh7d64z8rm8pr8m6khb80000gn/T/tmp740yw4sp
#   JVM stdout: /var/folders/qw/3c6hzh7d64z8rm8pr8m6khb80000gn/T/tmp740yw4sp/h2o_macbookair_started_from_python.out
#   JVM stderr: /var/folders/qw/3c6hzh7d64z8rm8pr8m6khb80000gn/T/tmp740yw4sp/h2o_macbookair_started_from_python.err
#   Server is running at http://127.0.0.1:54323
# Connecting to H2O server at http://127.0.0.1:54323... successful.
# ...
# --------------------------  ----------------------------------------
# H2O cluster uptime:         02 secs
# H2O cluster version:        3.14.0.7
# ...

# %%
mpd = pd.read_csv('mpd_wrangled.csv')
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (16,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mpd.isnull().sum()
# Out:
# Unnamed: 0                             0
# NPI                                    0
# Provider_Last_Name                     0
# Provider_First_Name                    0
# Specialty                              0
# Extended_Release_Opioid_Claims_2015    0
# Total_Claim_Count_2015                 0
# Opioid_Claim_Count_2015                0
# Total_Claim_Count_2014                 0
# Opioid_Claim_Count_2014                0
# Total_Claim_Count_2013                 0
# Opioid_Claim_Count_2013                0
# Entity_Type_Code                       0
# Practice_Address_Line1                 0
# Practice_Address_City                  0
# Practice_Address_State                 0
# Practice_Address_Zip                   0
# Practice_Address_Country               0
# Enumeration_Date                       0
# Deactivation_Reason_Code               0
# Reactivation_Date                      0
# Gender_Code                            0
# Is_Sole_Proprietor                     0
# ...

# %%
# location of "dirty" file
# decision trees handle dirty data elegantly
path = 'mpd_wrangled.csv'

# %%
# define input variable measurement levels 
# strings automatically parsed as enums (nominal)
# numbers automatically parsed as numeric
col_types = {'opioid_rate_2015': 'numeric'}

# %%
# define input variable measurement levels 
# strings automatically parsed as enums (nominal)
# numbers automatically parsed as numeric
col_types = {'Opioid_Claim_Count_2015': 'enum'}

# %%
frame = h2o.import_file(path=path, col_types=col_types) # multi-threaded import
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
frame.describe()
# Out:
# Rows:1094519
# Cols:35
# <table>
# <thead>
# ...

# %%
# split into 40% training, 30% validation, and 30% test
train, valid, test = frame.split_frame([0.4, 0.3])

# %%
# assign target and inputs
y = 'opioid_rate_2015'
X = [name for name in frame.columns if name not in ['Provider_Last_Name', 'Provider_First_Name', 'Practice_Address_Line1','Total_Claim_Count_2015', 'Practice_Address', y]]
print(y)
print(X)
# Out:
# opioid_rate_2015
# ['C1', 'NPI', 'Specialty', 'Extended_Release_Opioid_Claims_2015', 'Opioid_Claim_Count_2015', 'Total_Claim_Count_2014', 'Opioid_Claim_Count_2014', 'Total_Claim_Count_2013', 'Opioid_Claim_Count_2013', 'Entity_Type_Code', 'Practice_Address_City', 'Practice_Address_State', 'Practice_Address_Zip', 'Practice_Address_Country', 'Enumeration_Date', 'Deactivation_Reason_Code', 'Reactivation_Date', 'Gender_Code', 'Is_Sole_Proprietor', 'opioid_rate_2014', 'opioid_rate_2013', 'opioid_rate_pct_change_1yr', 'opioid_rate_pct_change_2yr', 'opioid_claim_change_1yr', 'opioid_claim_change_2yr', 'inactive_ind', 'specialty_std', 'entity_type_code_desc', 'Practice_Address_Zip5']

# %% [markdown]
# #set target to factor - for binary classification
# train[y] = train[y].asfactor()
# valid[y] = valid[y].asfactor()
# test[y] = test[y].asfactor()

# %%
# random forest

# initialize rf model
rf_model = H2ORandomForestEstimator(
    ntrees=500,                      # Up to 500 decision trees in the forest 
    max_depth=30,                    # trees can grow to depth of 30
    stopping_rounds=5,               # stop after validation error does not decrease for 5 iterations/new trees
    score_each_iteration=True,       # score validation error on every iteration/new tree
    model_id='rf_model')             # for easy lookup in flow

# train rf model
rf_model.train(
    x=X,
    y=y,
    training_frame=train,
    validation_frame=valid)

# print model information
#rf_model
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%
# Model Details
# ...
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  rf_model
#
#
# ModelMetricsRegression: drf
# ** Reported on train data. **
#
# MSE: 0.0010543147594137166
# RMSE: 0.03247021341805004
# MAE: 0.006910861455844728
# RMSLE: 0.023818309488421504
# Mean Residual Deviance: 0.0010543147594137166
#
# ModelMetricsRegression: drf
# ** Reported on validation data. **
#
# MSE: 0.0010164648230778096
# RMSE: 0.03188204546571329
# MAE: 0.006482661894150991
# RMSLE: 0.02338691558535176
# Mean Residual Deviance: 0.0010164648230778096
# Scoring History:
#      timestamp            duration           number_of_trees    training_rmse         training_mae           training_deviance      validation_rmse       validation_mae         validation_deviance
# ...

# %% [markdown]
# #measure rf AUC
# print(rf_model.auc(train=True))
# print(rf_model.auc(valid=True))
# print(rf_model.model_performance(test_data=test).auc())

# %%
rf_train = rf_model.model_performance(train=True)  #train=True is the default, so it's not needed
rf_train
# Out:
# ModelMetricsRegression: drf
# ** Reported on train data. **
#
# MSE: 0.0010543147594137166
# RMSE: 0.03247021341805004
# MAE: 0.006910861455844728
# RMSLE: 0.023818309488421504
# Mean Residual Deviance: 0.0010543147594137166

# %%
rf_valid = rf_model.model_performance(valid=True)  #train=True is the default, so it's not needed
rf_valid
# Out:
# ModelMetricsRegression: drf
# ** Reported on validation data. **
#
# MSE: 0.0010164648230778096
# RMSE: 0.03188204546571329
# MAE: 0.006482661894150991
# RMSLE: 0.02338691558535176
# Mean Residual Deviance: 0.0010164648230778096

# %%
# GBM with random hyperparameter search
# train many different GBM models with random hyperparameters
# and select best model based on validation error

# define random grid search parameters
hyper_parameters = {'ntrees':list(range(0, 500, 50)),
                    'max_depth':list(range(0, 20, 2)),
                    'sample_rate':[s/float(10) for s in range(1, 11)],
                    'col_sample_rate':[s/float(10) for s in range(1, 11)]}

# define search strategy
search_criteria = {'strategy':'RandomDiscrete',
                   'max_models':20,
                   'max_runtime_secs':600}

# initialize grid search
gsearch = H2OGridSearch(H2OGradientBoostingEstimator,
                        hyper_params=hyper_parameters,
                        search_criteria=search_criteria)

# execute training w/ grid search
gsearch.train(x=X,
              y=y,
              training_frame=train,
              validation_frame=valid)
# Out:
# gbm Grid Build progress: |████████████████████████████████████████████████| 100%
# Errors/Warnings building gridsearch model
#
# Hyper-parameter: col_sample_rate, 0.1
# Hyper-parameter: max_depth, 0
# Hyper-parameter: ntrees, 50
# Hyper-parameter: sample_rate, 0.1
# failure_details: Illegal argument(s) for GBM model: Grid_GBM_py_11_sid_a5b6_model_python_1523471527611_1_model_9.  Details: ERRR on field: _max_depth: _max_depth must be > 0.
#
# failure_stack_traces: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: Grid_GBM_py_11_sid_a5b6_model_python_1523471527611_1_model_9.  Details: ERRR on field: _max_depth: _max_depth must be > 0.
#
# 	at water.exceptions.H2OModelBuilderIllegalArgumentException.makeFromBuilder(H2OModelBuilderIllegalArgumentException.java:20)
# 	at hex.tree.gbm.GBM.init(GBM.java:84)
# 	at hex.tree.SharedTree$Driver.computeImpl(SharedTree.java:194)
# 	at hex.ModelBuilder$Driver.compute2(ModelBuilder.java:173)
# ...

# %%
# show grid search results
gsearch.show()

# select best model
gbm_model = gsearch.get_grid()[0]

# print model information
gbm_model
# Out:
#     col_sample_rate max_depth ntrees sample_rate  \
# 0               0.7        12    450         0.6
# 1               0.7         6    150         0.5
# 2               0.4        18    300         0.9
# 3               1.0        10    400         0.3
# 4               0.7         4    450         0.7
# 5               1.0        10    250         0.2
# 6               0.7         2    200         0.3
# 7               0.2         2    400         0.1
# 8               0.4         2    100         0.7
# 9               0.5         6      0         0.7
#
#                                                        model_ids  \
# 0   Grid_GBM_py_11_sid_a5b6_model_python_1523471527611_1_model_3
# 1  Grid_GBM_py_11_sid_a5b6_model_python_1523471527611_1_model_10
# 2   Grid_GBM_py_11_sid_a5b6_model_python_1523471527611_1_model_0
# 3   Grid_GBM_py_11_sid_a5b6_model_python_1523471527611_1_model_2
# 4   Grid_GBM_py_11_sid_a5b6_model_python_1523471527611_1_model_5
# ...

# %%
gbm_model._model_json['output']['variable_importances'].as_data_frame()
# Out:
#                                variable  relative_importance  \
# 0                      opioid_rate_2014         31700.167969
# 1            opioid_rate_pct_change_1yr          3837.534424
# 2                      opioid_rate_2013          2406.191406
# 3               opioid_claim_change_2yr          2173.644043
# 4                             Specialty          1285.474365
# 5            opioid_rate_pct_change_2yr          1163.060913
# 6               Opioid_Claim_Count_2015          1147.204712
# 7                         specialty_std           856.882263
# 8                Total_Claim_Count_2014           578.396240
# 9                Practice_Address_State           544.535583
# 10              opioid_claim_change_1yr           212.861877
# 11                     Enumeration_Date           165.199127
# 12                Practice_Address_City           123.363716
# 13               Total_Claim_Count_2013            98.817810
# ...

# %%
gbm_model.plot()

# %% [markdown]
# ### Geocode

# %%
def str_join(df, sep, *cols):
    from functools import reduce
    return reduce(lambda x, y: x.astype(str).str.cat(y.astype(str), sep=sep),
                  [df[col] for col in cols])

# %%
mpd['Practice_Address'] = str_join(mpd, ',', 'Practice_Address_Line1', 'Practice_Address_City', 'Practice_Address_State', 'Practice_Address_Zip5', 'Practice_Address_Country')

# %%
mpd_test = mpd[1:10]

# %%
mpd_test
# Out:
#           NPI Provider_Last_Name Provider_First_Name Gender_Code  \
# 1  1861499576          SEVERTSON                MARK           M
# 2  1255338893           MILUNSKI                MARK           M
# 3  1255338802           STAFFORD            PATRICIA           F
# 4  1962409524            KARPATI             ADRIANA           F
# 5  1740284272            CORBETT               DAVID           M
# 6  1386648822               DERY           MARKALAIN           M
# 7  1003810540            HOLSTEN             RAYMOND           M
# 8  1912901455              KARCH              ROBERT           M
# 9  1902801327           WARBASSE            LAWRENCE           M
#
#   Is_Sole_Proprietor         Specialty_std Entity_Type_Code_desc  \
# 1                  N        Otolaryngology            Individual
# 2                  N     Internal Medicine            Individual
# 3                  Y  Diagnostic Radiology            Individual
# ...

# %%
"""
Python script for batch geocoding of addresses using the Google Geocoding API.
This script allows for massive lists of addresses to be geocoded for free by pausing when the 
geocoder hits the free rate limit set by Google (2500 per day).  If you have an API key for paid
geocoding from Google, set it in the API key section.
Addresses for geocoding can be specified in a list of strings "addresses". In this script, addresses
come from a csv file with a column "Address". Adjust the code to your own requirements as needed.
After every 500 successul geocode operations, a temporary file with results is recorded in case of 
script failure / loss of connection later.
Addresses and data are held in memory, so this script may need to be adjusted to process files line
by line if you are processing millions of entries.
Shane Lynn
5th November 2016
"""

import pandas as pd
import requests
import logging
import time

logger = logging.getLogger("root")
logger.setLevel(logging.DEBUG)
# create console handler
ch = logging.StreamHandler()
ch.setLevel(logging.DEBUG)
logger.addHandler(ch)

#------------------ CONFIGURATION -------------------------------

# Set your Google API key here. 
# Even if using the free 2500 queries a day, its worth getting an API key since the rate limit is 50 / second.
# With API_KEY = None, you will run into a 2 second delay every 10 requests or so.
# With a "Google Maps Geocoding API" key from https://console.developers.google.com/apis/, 
# the daily limit will be 2500, but at a much faster rate.
# Example: API_KEY = 'AIzaSyC9azed9tLdjpZNjg2_kVePWvMIBq154eA'
API_KEY = None
# Backoff time sets how many minutes to wait between google pings when your API limit is hit
BACKOFF_TIME = 30
# Set your output file name here.
output_filename = "mpd_address.csv"
# Set your input file here
input_filename = mpd
# Specify the column name in your input data that contains addresses here
address_column_name = "Practice_Address"
# Return Full Google Results? If True, full JSON results from Google are included in output
RETURN_FULL_RESULTS = False

#------------------ DATA LOADING --------------------------------

# Read the data to a Pandas Dataframe
data = input_filename

if address_column_name not in data.columns:
	raise ValueError("Missing Address column in input data")

# Form a list of addresses for geocoding:
# Make a big list of all of the addresses to be processed.
addresses = data[address_column_name].tolist()

# **** DEMO DATA / IRELAND SPECIFIC! ****
# We know that these addresses are in Ireland, and there's a column for county, so add this for accuracy. 
# (remove this line / alter for your own dataset)
#####addresses = (data[address_column_name] + ',' + data['County'] + ',Ireland').tolist()


#------------------	FUNCTION DEFINITIONS ------------------------

def get_google_results(address, api_key=None, return_full_response=False):
    """
    Get geocode results from Google Maps Geocoding API.
    
    Note, that in the case of multiple google geocode reuslts, this function returns details of the FIRST result.
    
    @param address: String address as accurate as possible. For Example "18 Grafton Street, Dublin, Ireland"
    @param api_key: String API key if present from google. 
                    If supplied, requests will use your allowance from the Google API. If not, you
                    will be limited to the free usage of 2500 requests per day.
    @param return_full_response: Boolean to indicate if you'd like to return the full response from google. This
                    is useful if you'd like additional location details for storage or parsing later.
    """
    # Set up your Geocoding url
    geocode_url = "https://maps.googleapis.com/maps/api/geocode/json?address={}".format(address)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
        
    # Ping google for the reuslts:
    results = requests.get(geocode_url)
    # Results will be in JSON format - convert to dict using requests functionality
    results = results.json()
    
    # if there's no results or an error, return empty results.
    if len(results['results']) == 0:
        output = {
            "formatted_address" : None,
            "latitude": None,
            "longitude": None,
            "accuracy": None,
            "google_place_id": None,
            "type": None,
            "postcode": None
        }
    else:    
        answer = results['results'][0]
        output = {
            "formatted_address" : answer.get('formatted_address'),
            "latitude": answer.get('geometry').get('location').get('lat'),
            "longitude": answer.get('geometry').get('location').get('lng'),
            "accuracy": answer.get('geometry').get('location_type'),
            "google_place_id": answer.get("place_id"),
            "type": ",".join(answer.get('types')),
            "postcode": ",".join([x['long_name'] for x in answer.get('address_components') 
                                  if 'postal_code' in x.get('types')])
        }
        
    # Append some other details:    
    output['input_string'] = address
    output['number_of_results'] = len(results['results'])
    output['status'] = results.get('status')
    if return_full_response is True:
        output['response'] = results
    
    return output

#------------------ PROCESSING LOOP -----------------------------

# Ensure, before we start, that the API key is ok/valid, and internet access is ok
test_result = get_google_results("London, England", API_KEY, RETURN_FULL_RESULTS)
if (test_result['status'] != 'OK') or (test_result['formatted_address'] != 'London, UK'):
    logger.warning("There was an error when testing the Google Geocoder.")
    raise ConnectionError('Problem with test results from Google Geocode - check your API key and internet connection.')

# Create a list to hold results
results = []
# Go through each address in turn
for address in addresses:
    # While the address geocoding is not finished:
    geocoded = False
    while geocoded is not True:
        # Geocode the address with google
        try:
            geocode_result = get_google_results(address, API_KEY, return_full_response=RETURN_FULL_RESULTS)
        except Exception as e:
            logger.exception(e)
            logger.error("Major error with {}".format(address))
            logger.error("Skipping!")
            geocoded = True
            
        # If we're over the API limit, backoff for a while and try again later.
        if geocode_result['status'] == 'OVER_QUERY_LIMIT':
            logger.info("Hit Query Limit! Backing off for a bit.")
            time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
            geocoded = False
        else:
            # If we're ok with API use, save the results
            # Note that the results might be empty / non-ok - log this
            if geocode_result['status'] != 'OK':
                logger.warning("Error geocoding {}: {}".format(address, geocode_result['status']))
            logger.debug("Geocoded: {}: {}".format(address, geocode_result['status']))
            results.append(geocode_result)           
            geocoded = True

    # Print status every 100 addresses
    if len(results) % 100 == 0:
    	logger.info("Completed {} of {} address".format(len(results), len(addresses)))
            
    # Every 500 addresses, save progress to file(in case of a failure so you have something!)
    if len(results) % 500 == 0:
        pd.DataFrame(results).to_csv("{}_bak".format(output_filename))

# All done
logger.info("Finished geocoding all addresses")
# Write the full results to csv using the pandas library.
pd.DataFrame(results).to_csv(output_filename, encoding='utf8')
# Out:
# Geocoded: 2106 HARRISBURG PIKE,LANCASTER,PA,17604,US: OK
# Hit Query Limit! Backing off for a bit.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-5d60078d2a4f> in <module>()
#     149         if geocode_result['status'] == 'OVER_QUERY_LIMIT':
#     150             logger.info("Hit Query Limit! Backing off for a bit.")
# --> 151             time.sleep(BACKOFF_TIME * 60) # sleep for 30 minutes
#     152             geocoded = False
#     153         else:
#
# KeyboardInterrupt:

# %%
from ipywidgets import FloatProgress
from IPython.display import display
import time

max_count = 100

f = FloatProgress(min=0, max=max_count) # instantiate the bar
display(f) # display the bar

count = 0
while count <= max_count:
    f.value += 1 # signal to increment the progress bar
    time.sleep(.1)
    count += 1

# %% [markdown]
# # Zip code level analysis

# %%
zipcd =pd.read_csv("final_zip_summary_v001.csv", sep='|', engine='python')

# %%
zipcd.head(5)
# Out:
#   Practice_Address_Zip5 city stabbr  year  total_NPIs  Total_Claim_Count  \
# 0                 00000  NaN    NaN  2013           1                139
# 1                   001  NaN    NaN  2013           1                 68
# 2                 00604  NaN    NaN  2014          10              49161
# 3                 00611  NaN    NaN  2013           4              20606
# 4                 00613  NaN    NaN  2013          19              40743
#
#    Total_Opioid_Claim_Count  total_2010_pop  Total_Employees  \
# 0                        23             NaN              NaN
# 1                         0             NaN              NaN
# 2                       494             NaN              NaN
# 3                      1050             NaN              NaN
# 4                       848             NaN              NaN
#
#    Total_Annual_Payroll_1000s         ...          \
# 0                         NaN         ...
# 1                         NaN         ...
# ...

# %% [markdown]
# print(zipcd.shape)

# %%
zipcd.isnull().sum()
# Out:
# Practice_Address_Zip5                       6
# city                                     2316
# stabbr                                   2316
# year                                        0
# total_NPIs                                  0
# Total_Claim_Count                           0
# Total_Opioid_Claim_Count                    0
# total_2010_pop                           5127
# Total_Employees                          2316
# Total_Annual_Payroll_1000s               2316
# Total_Establishments                     2316
# Total_Tax_Returns                       15347
# Total_Single_Returns                    15347
# Total_Joint_Returns                     15347
# Total_HeadOfHousehold_Returns           15347
# Total_Dependents                        15347
# Total_AGI_1000s                         15347
# Total_Income_1000s                      15347
# Total_Farm_Returns                      15347
# Total_Unemp_Comp_Returns                15347
# ...

# %%
zipcd = zipcd.dropna()

# %%
print(zipcd.shape)
# Out:
# (45575, 24)

# %%
zipcd.to_csv("zipcd_wrangled.csv")

# %% [markdown]
# ### Zip Code Base_Random Forest Analysis

# %%
import h2o 
from h2o.estimators.gbm import H2OGradientBoostingEstimator 
from h2o.estimators.random_forest import H2ORandomForestEstimator
from h2o.grid.grid_search import H2OGridSearch

# %%
# display matplotlib graphics in notebook
# %matplotlib inline

# %%
# start and connect to h2o server
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: java version "1.8.0_111"; Java(TM) SE Runtime Environment (build 1.8.0_111-b14); Java HotSpot(TM) 64-Bit Server VM (build 25.111-b14, mixed mode)
#   Starting server from /Users/macbookair/anaconda3/lib/python3.6/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/qw/3c6hzh7d64z8rm8pr8m6khb80000gn/T/tmpjnjytn3o
#   JVM stdout: /var/folders/qw/3c6hzh7d64z8rm8pr8m6khb80000gn/T/tmpjnjytn3o/h2o_macbookair_started_from_python.out
#   JVM stderr: /var/folders/qw/3c6hzh7d64z8rm8pr8m6khb80000gn/T/tmpjnjytn3o/h2o_macbookair_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321... successful.
# --------------------------  ----------------------------------------
# H2O cluster uptime:         03 secs
# H2O cluster timezone:       America/Los_Angeles
# ...

# %%
# location of "dirty" file
# decision trees handle dirty data elegantly
path = 'zipcd_wrangled.csv'

# %%
# define input variable measurement levels 
# strings automatically parsed as enums (nominal)
# numbers automatically parsed as numeric
col_types = {'Total_Opioid_Claim_Count': 'numeric'}

# %%
frame = h2o.import_file(path=path, col_types=col_types) # multi-threaded import
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
frame.describe()
# Out:
# Rows:45575
# Cols:25
# <table>
# <thead>
# <tr><th>       </th><th>C1               </th><th>Practice_Address_Zip5  </th><th>city            </th><th>stabbr  </th><th>year              </th><th>total_NPIs        </th><th>Total_Claim_Count  </th><th>Total_Opioid_Claim_Count  </th><th>total_2010_pop    </th><th>Total_Employees  </th><th>Total_Annual_Payroll_1000s  </th><th>Total_Establishments  </th><th>Total_Tax_Returns  </th><th>Total_Single_Returns  </th><th>Total_Joint_Returns  </th><th>Total_HeadOfHousehold_Returns  </th><th>Total_Dependents  </th><th>Total_AGI_1000s   </th><th>Total_Income_1000s  </th><th>Total_Farm_Returns  </th><th>Total_Unemp_Comp_Returns  </th><th>Total_Mortgate_Interest_Paid_Returns  </th><th>Total_AMT_Returns  </th><th>Total_EIC_Returns  </th><th>Total_ACTC_Returns  </th></tr>
# </thead>
# <tbody>
# ...

# %%
# split into 40% training, 30% validation, and 30% test
train, valid, test = frame.split_frame([0.4, 0.3])

# %%
# assign target and inputs
y = 'Total_Opioid_Claim_Count'
X = [name for name in frame.columns if name not in ['Practice_Address_Zip5', 'city', 'stabbr', 'year', '_WARN_', y]]
print(y)
print(X)
# Out:
# Total_Opioid_Claim_Count
# ['C1', 'total_NPIs', 'Total_Claim_Count', 'total_2010_pop', 'Total_Employees', 'Total_Annual_Payroll_1000s', 'Total_Establishments', 'Total_Tax_Returns', 'Total_Single_Returns', 'Total_Joint_Returns', 'Total_HeadOfHousehold_Returns', 'Total_Dependents', 'Total_AGI_1000s', 'Total_Income_1000s', 'Total_Farm_Returns', 'Total_Unemp_Comp_Returns', 'Total_Mortgate_Interest_Paid_Returns', 'Total_AMT_Returns', 'Total_EIC_Returns', 'Total_ACTC_Returns']

# %%
# random forest

# initialize rf model
rf_model = H2ORandomForestEstimator(
    ntrees=500,                      # Up to 500 decision trees in the forest 
    max_depth=30,                    # trees can grow to depth of 30
    stopping_rounds=5,               # stop after validation error does not decrease for 5 iterations/new trees
    score_each_iteration=True,       # score validation error on every iteration/new tree
    model_id='rf_model')             # for easy lookup in flow

# train rf model
rf_model.train(
    x=X,
    y=y,
    training_frame=train,
    validation_frame=valid)

# print model information
rf_model

# view detailed results at http://localhost:54321/flow/index.html
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%
# Model Details
# ...
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  rf_model
#
#
# ModelMetricsRegression: drf
# ** Reported on train data. **
#
# MSE: 5960312.850245838
# RMSE: 2441.375196532855
# MAE: 1046.5096576419826
# RMSLE: 1.201917755999907
# Mean Residual Deviance: 5960312.850245838
#
# ModelMetricsRegression: drf
# ** Reported on validation data. **
#
# MSE: 5651978.523077232
# RMSE: 2377.389013829506
# MAE: 1020.7607770658009
# RMSLE: 1.237782541707578
# Mean Residual Deviance: 5651978.523077232
# Scoring History:
#      timestamp            duration    number_of_trees    training_rmse       training_mae        training_deviance    validation_rmse     validation_mae      validation_deviance
# ---  -------------------  ----------  -----------------  ------------------  ------------------  -------------------  ------------------  ------------------  ---------------------
# ...

# %%
# GBM with random hyperparameter search
# train many different GBM models with random hyperparameters
# and select best model based on validation error

# define random grid search parameters
hyper_parameters = {'ntrees':list(range(0, 500, 50)),
                    'max_depth':list(range(0, 20, 2)),
                    'sample_rate':[s/float(10) for s in range(1, 11)],
                    'col_sample_rate':[s/float(10) for s in range(1, 11)]}

# define search strategy
search_criteria = {'strategy':'RandomDiscrete',
                   'max_models':20,
                   'max_runtime_secs':600}

# initialize grid search
gsearch = H2OGridSearch(H2OGradientBoostingEstimator,
                        hyper_params=hyper_parameters,
                        search_criteria=search_criteria)

# execute training w/ grid search
gsearch.train(x=X,
              y=y,
              training_frame=train,
              validation_frame=valid)

# view detailed results at http://localhost:54321/flow/index.html
# Out:
# gbm Grid Build progress: |████████████████████████████████████████████████| 100%
# Errors/Warnings building gridsearch model
#
# Hyper-parameter: col_sample_rate, 0.6
# Hyper-parameter: max_depth, 0
# Hyper-parameter: ntrees, 450
# Hyper-parameter: sample_rate, 0.8
# failure_details: Illegal argument(s) for GBM model: Grid_GBM_py_3_sid_a76a_model_python_1524247712537_1_model_17.  Details: ERRR on field: _max_depth: _max_depth must be > 0.
#
# failure_stack_traces: water.exceptions.H2OModelBuilderIllegalArgumentException: Illegal argument(s) for GBM model: Grid_GBM_py_3_sid_a76a_model_python_1524247712537_1_model_17.  Details: ERRR on field: _max_depth: _max_depth must be > 0.
#
# 	at water.exceptions.H2OModelBuilderIllegalArgumentException.makeFromBuilder(H2OModelBuilderIllegalArgumentException.java:20)
# 	at hex.tree.gbm.GBM.init(GBM.java:84)
# 	at hex.tree.SharedTree$Driver.computeImpl(SharedTree.java:203)
# 	at hex.ModelBuilder$Driver.compute2(ModelBuilder.java:206)
# ...

# %%
# show grid search results
gsearch.show()

# select best model
gbm_model = gsearch.get_grid()[0]

# print model information
gbm_model
# Out:
#      col_sample_rate max_depth ntrees sample_rate  \
# 0                0.8        14    250         0.8
# 1                0.2        12    300         0.7
# 2                0.4        10    150         0.8
# 3                0.8        14    350         0.5
# 4                0.8        14    250         0.5
# 5                0.7        18    300         0.4
# 6                0.2        16    150         0.6
# 7                0.7         8    150         0.7
# 8                0.4         6    250         0.7
# 9                0.6        12    200         0.4
# 10               0.8         6    100         0.9
# 11               0.9         8     50         0.6
# 12               0.4        16    100         0.3
# 13               0.1        16    100         0.8
# 14               0.5         4    150         0.9
# 15               0.3        18    200         0.2
# 16               0.6        10     50         0.1
# 17               0.3         8      0         0.3
# ...

# %%
gbm_model._model_json['output']['variable_importances'].as_data_frame()
# Out:
#                                 variable  relative_importance  \
# 0                      Total_Claim_Count         4.270262e+12
# 1                             total_NPIs         6.200136e+11
# 2                                     C1         1.195804e+11
# 3                   Total_Single_Returns         9.432055e+10
# 4                     Total_Farm_Returns         7.855276e+10
# 5                      Total_AMT_Returns         5.364536e+10
# 6                   Total_Establishments         4.366840e+10
# 7                        Total_Employees         3.854143e+10
# 8   Total_Mortgate_Interest_Paid_Returns         3.642209e+10
# 9                      Total_EIC_Returns         3.604673e+10
# 10                   Total_Joint_Returns         3.171253e+10
# 11                      Total_Dependents         3.096480e+10
# 12                        total_2010_pop         2.967566e+10
# 13              Total_Unemp_Comp_Returns         2.943511e+10
# ...

# %%
# partial dependence plots are a powerful machine learning interpretation tool
# to calculate partial dependence across the domain a variable
# hold column of interest at constant value
# find the mean prediction of the model with this column constant
# repeat for multiple values of the variable of interest
# h2o has a built-in function for partial dependence as well
par_dep_dti1 = gbm_model.partial_plot(data=train, cols=['Total_Claim_Count'], server=True, plot=True)
# Out:
# PartialDependencePlot progress: |█████████████████████████████████████████| 100%

# %%
par_dep_dti1 = gbm_model.partial_plot(data=train, cols=['total_NPIs'], server=True, plot=True)
# Out:
# PartialDependencePlot progress: |█████████████████████████████████████████| 100%

# %%
# shutdown h2o
h2o.cluster().shutdown(prompt=False)
# Out:
# H2O session _sid_a76a closed.

# %% [markdown]
# ### Zip Code Base_Linear Regression Analysis

# %%
import time         # for timers
import h2o
from h2o.estimators.glm import H2OGeneralizedLinearEstimator

# %%
# data-related constants
IN_FILE_PATH = 'zipcd_wrangled.csv'
Y            = 'Total_Claim_Count'
DROPS        = ['Practice_Address_Zip5', 'city', 'stabbr', 'year', 'Total_Opioid_Claim_Count']

# model-related constants
LEARN_RATE   = 0.005 # how much each gradient descent step impacts parameters
CONV         = 1e-10 # desired precision in parameters 
MAX_ITERS    = 10000 # maximum number of gradient descent steps to allow

# %%
# import data using Pandas
raw = pd.read_csv(IN_FILE_PATH)

# %%
# select target column
y = raw[Y].as_matrix()
print(y)
# Out:
# [56083  6406   225 ...   172  3232 40919]

# %%
# create input matrix
# add an additional column of 1's for intercept 
# by overlaying inputs onto matrix of 1's
numeric = raw.drop(DROPS + [Y], axis=1).as_matrix()
N, p = numeric.shape
X = np.ones(shape=(N, p + 1))
X[:,1:] = numeric 
print(X)
# Out:
# [[1.0000e+00 7.8000e+01 3.2000e+01 ... 9.0000e+01 1.0000e+03 5.4000e+02]
#  [1.0000e+00 8.1000e+01 6.0000e+00 ... 4.0000e+01 1.9000e+02 9.0000e+01]
#  [1.0000e+00 8.2000e+01 9.0000e+00 ... 3.0000e+01 2.4600e+03 1.5600e+03]
#  ...
#  [1.0000e+00 6.0904e+04 3.0000e+00 ... 0.0000e+00 3.0000e+02 3.0000e+02]
#  [1.0000e+00 6.0905e+04 6.0000e+00 ... 0.0000e+00 2.3000e+02 1.7000e+02]
#  [1.0000e+00 6.0911e+04 5.0000e+01 ... 5.0000e+01 8.6000e+02 5.0000e+02]]

# %% [markdown]
# #### Define squared loss function
# For linear regression, we minimize the squared distance between the regression plane and points in the conditional distribution of y given X.
# It is convenient to use a scaled mean squared error (MSE) formula:

# %%
def squared_loss(n, x, y, betas):
    
    """ Squared loss function for multiple linear regression.
    
    :param n: Number of rows in x.
    :param x: Matrix of numeric inputs.
    :param y: Vector of known target values.
    :param beta: Vector or current model parameters.
    :return: Scalar MSE value.    
    
    """
    
    yhat = x.dot(betas)
        
    return ((1 / (2 * n)) * (y - yhat)**2).sum()

# %% [markdown]
# #### Define gradient of loss function
# The derivative of the loss function w.r.t the model parameters is used to update model parameters at each gradient descent step.
# The gradient of our MSE loss function is trivial:

# %%
def grad(n, y, yhat):
    
    """ Analytical gradient of scaled MSE loss function.
    
    :param n: Number of rows in X.
    :param y: Vector of known target values.
    :param yhat: Vector of predicted target values.
    :return: Vector of gradient values.
    
    """
    
    return ((1 / n)*(yhat - y))

# %% [markdown]
# #### Define function for executing gradient descent minimization
# For each gradient descent step:
#
# Predictions are made using the current model parameters.
# The gradient is calculated for each model pararmeter.
# The gradient is used in combination with the learning rate to update each parameter.

# %%
def grad_descent(X, y, learn_rate, max_iters, sgd_mini_batch_n=0):
    
    """ Routine for executing simple gradient descent with stochastic gradient descent option.
    
    :param X: Matrix of numeric data.
    :param y: Vector of known target values.
    :param learn_rate: Learning rate.
    :param max_iters: Maximum number of gradient descent steps to perform.
    :param sgd_mini_batch_n: Minibatch size for sgd optimization.
                             If > 0 minibatch stochastic gradient descent is performed.
    
    """

    tic = time.time()               # start timer
    n_betas = X.shape[1]            # number of model parameters including bias    
    betas = np.zeros(shape=n_betas) # parameters start with value of 0
    n = y.shape[0]                  # number of rows in X
    
    # Pandas dataframe for iteration history
    iteration_frame = pd.DataFrame(columns=['Iteration', 'Loss'])

    print('Iteration history:')
    
    # loop for gradient descent steps
    for i in range(max_iters):
        
        # stochastic gradient descent
        if sgd_mini_batch_n > 0:
            
            samp_idx = np.random.randint(n, size=sgd_mini_batch_n)
            X_samp = X[samp_idx, :]
            y_samp = y[samp_idx]
            n_samp = X_samp.shape[0]
            yhat_samp = X_samp.dot(betas) # model predictions for iteration

            # loop for column-wise parameter updates
            for j in range(n_betas):

                # select column
                # calculate column-wise gradient
                # update corresponding parameter based on negative gradient
                # calculate loss

                xj_samp = X_samp[:, j]
                xj_grad_samp = grad(n_samp, y_samp, yhat_samp) * xj_samp
                betas[j] = betas[j] - learn_rate * xj_grad_samp.sum()
                iter_loss = squared_loss(n_samp, X_samp, y_samp, betas)
        
        # standard gradient descent
        else:
            
            yhat = X.dot(betas) # model predictions for iteration

            # loop for column-wise parameter updates
            for j in range(n_betas):
                xj = X[:, j]
                xj_grad = grad(n, y, yhat) * xj
                betas[j] = betas[j] - learn_rate * xj_grad.sum()
                iter_loss = squared_loss(n, X, y, betas)
        
        # update loss history
        iteration_frame = iteration_frame.append({'Iteration': i,
                                                  'Loss':  iter_loss}, 
                                                  ignore_index=True)        
        # progress indicator 
        if i % 1000 == 0:
            print('iter=%d loss=%.6f' % (i, iter_loss))
        
        # convergence check
        if i > 0:
            if np.abs(iteration_frame.iat[i-1, 1] - iteration_frame.iat[i, 1]) < CONV:
                break

    # output 
    # %matplotlib inline
    iteration_frame.plot.line(title='Iteration Plot', x='Iteration', y='Loss')
    print()           
    print('Model parameters at iteration ' + str(i) + ':')
    print(betas)
    print()
    print('Model trained in %.2f s.' % (time.time()-tic))

# %%
grad_descent(X, y, 0.005, 10)
# Out:
# Iteration history:
# iter=0 loss=308905905756423944884686159872.000000
#
# Model parameters at iteration 9:
# [-1.04713810e+92 -3.40012890e+96 -1.43460672e+94 -3.10936178e+96
#  -1.60657529e+96 -1.01547504e+98 -9.62406362e+94 -1.52124471e+96
#  -7.40325664e+95 -5.53327089e+95 -1.98512333e+95 -9.55615954e+95
#  -1.48953903e+98 -1.51104465e+98 -5.55041909e+93 -7.07120536e+94
#  -3.95430530e+95 -8.22165278e+94 -2.38713992e+95 -1.66759734e+95]
#
# Model trained in 0.69 s.

# %%
grad_descent(X, y, LEARN_RATE, 10, sgd_mini_batch_n=1000)
# Out:
# Iteration history:
# iter=0 loss=320871037511404947018310746112.000000
#
# Model parameters at iteration 9:
# [-6.91239109e+91 -2.19945160e+96 -1.17236792e+94 -1.99963560e+96
#  -1.17095813e+96 -9.33506471e+97 -7.09810784e+94 -9.84572236e+95
#  -4.80594524e+95 -3.59667777e+95 -1.23823155e+95 -6.07819815e+95
#  -1.32408908e+98 -1.34191773e+98 -3.59860495e+93 -4.46342513e+94
#  -2.71545954e+95 -6.70362439e+94 -1.45302768e+95 -1.03189446e+95]
#
# Model trained in 0.08 s.

# %%
# start h2o
h2o.init()

DROPS = ['Practice_Address_Zip5', 'city', 'stabbr', 'year', 'Total_Opioid_Claim_Count']

# numeric columns 
train = h2o.import_file(IN_FILE_PATH)
train = train.drop(DROPS)
X = train.col_names

# initialize non-penalized GLM model
loan_glm = H2OGeneralizedLinearEstimator(family='gaussian',      # uses squared error
                                         solver='IRLSM',         # necessary for non-penalized GLM
                                         standardize=False,      # data is already standardized
                                         compute_p_values=True,  # necessary for non-penalized GLM 
                                         lambda_=0)              # necessary for non-penalized GLM

# train 
loan_glm.train(train.col_names, Y, training_frame=train)

# print trained model info
print() 
print('Model parameters:')
for name, val in loan_glm.coef().items():
    print(name, val)
print()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: java version "1.8.0_111"; Java(TM) SE Runtime Environment (build 1.8.0_111-b14); Java HotSpot(TM) 64-Bit Server VM (build 25.111-b14, mixed mode)
#   Starting server from /Users/macbookair/anaconda3/lib/python3.6/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /var/folders/qw/3c6hzh7d64z8rm8pr8m6khb80000gn/T/tmpwa9w9ucx
#   JVM stdout: /var/folders/qw/3c6hzh7d64z8rm8pr8m6khb80000gn/T/tmpwa9w9ucx/h2o_macbookair_started_from_python.out
#   JVM stderr: /var/folders/qw/3c6hzh7d64z8rm8pr8m6khb80000gn/T/tmpwa9w9ucx/h2o_macbookair_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321... successful.
# --------------------------  ----------------------------------------
# H2O cluster uptime:         02 secs
# H2O cluster timezone:       America/Los_Angeles
# ...

# %%
loan_glm
# Out:
# Model Details
# ...
# H2OGeneralizedLinearEstimator :  Generalized Linear Modeling
# Model Key:  GLM_model_python_1524449026509_1
#
#
# ModelMetricsRegressionGLM: glm
# ** Reported on train data. **
#
# MSE: 4436242541.093504
# RMSE: 66605.12398527237
# MAE: 33891.88488943625
# RMSLE: NaN
# R^2: 0.7380754003865014
# Mean Residual Deviance: 4436242541.093504
# Null degrees of freedom: 45574
# Residual degrees of freedom: 45555
# Null deviance: 771908228966198.5
# Residual deviance: 202181753810336.44
# AIC: 1141739.0757360659
# Scoring History:
#     timestamp            duration    iterations    negative_log_likelihood    objective
# --  -------------------  ----------  ------------  -------------------------  -----------
#     2018-04-22 19:03:51  0.000 sec   0             7.71908e+14                1.69371e+10

# %%
zipcd_wrangled =pd.read_csv("zipcd_wrangled.csv")
zipcd2015 = zipcd_wrangled[zipcd_wrangled['year'] == 2015]

# %%
zipcd2015 = h2o.H2OFrame(zipcd2015)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
pred = loan_glm.predict(zipcd2015)
# Out:
# glm prediction progress: |████████████████████████████████████████████████| 100%
# /Users/macbookair/anaconda3/lib/python3.6/site-packages/h2o/job.py:69: UserWarning: Test/Validation dataset is missing column 'C1': substituting in a column of NaN
#   warnings.warn(w)

# %%
pred.describe()
# Out:
# Rows:17877
# Cols:2
# <table>
# <thead>
# <tr><th>       </th><th>predict            </th><th>StdErr            </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>real               </td><td>real              </td></tr>
# <tr><td>mins   </td><td>-271169.91626100894</td><td>388.2162522657808 </td></tr>
# <tr><td>mean   </td><td>75065.92389052626  </td><td>1037.9317191989724</td></tr>
# <tr><td>maxs   </td><td>2979067.711241253  </td><td>14667.06852038064 </td></tr>
# <tr><td>sigma  </td><td>110896.52336988755 </td><td>877.006340973224  </td></tr>
# <tr><td>zeros  </td><td>0                  </td><td>0                 </td></tr>
# <tr><td>missing</td><td>0                  </td><td>0                 </td></tr>
# <tr><td>0      </td><td>3492.46271553798   </td><td>526.8827983659011 </td></tr>
# <tr><td>1      </td><td>22052.14191738629  </td><td>936.9433365217296 </td></tr>
# <tr><td>2      </td><td>457306.5345764635  </td><td>1880.444618192127 </td></tr>
# ...

# %%
# create time stamp
import re
import time
time_stamp = re.sub('[: ]', '_', time.asctime())

# score unlabeled test data
sub = loan_glm.predict(zipcd2015)

# save file for submission
sub = sub['predict']

import numpy as np # create ID column
sub = h2o.H2OFrame(np.arange(1, 17878)).cbind(sub) 

sub.columns = ['predict', 'StdErr']

print(sub.head())

sub_fname = str(time_stamp) + '.csv'
h2o.download_csv(sub, sub_fname)
# Out:
# glm prediction progress: |████████████████████████████████████████████████| 100%
# /Users/macbookair/anaconda3/lib/python3.6/site-packages/h2o/job.py:69: UserWarning: Test/Validation dataset is missing column 'C1': substituting in a column of NaN
#   warnings.warn(w)
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th><th style="text-align: right;">   StdErr</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;">        1</td><td style="text-align: right;">  3492.46</td></tr>
# <tr><td style="text-align: right;">        2</td><td style="text-align: right;"> 22052.1 </td></tr>
# <tr><td style="text-align: right;">        3</td><td style="text-align: right;">457307   </td></tr>
# <tr><td style="text-align: right;">        4</td><td style="text-align: right;"> 19005.2 </td></tr>
# ...

# %%
export_file(pred, "pred2015.csv", force=False, parts=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-cb5be647f17d> in <module>()
# ----> 1 export_file(pred, "pred2015.csv", force=False, parts=1)
#
# <ipython-input-30-35df4d4394de> in export_file(frame, path, force, parts)
#      12         Default is ``parts = 1``, which is to export to a single file.
#      13     """
# ---> 14     assert_is_type(frame, H2OFrame)
#      15     assert_is_type(path, str)
#      16     assert_is_type(force, bool)
#
# NameError: name 'assert_is_type' is not defined

# %%
pred = h2o.predict(binomial.fit, test)
h2o.exportFile(pred, "/tmp/pred.csv", force = TRUE)

# %%
# shutdown h2o
h2o.cluster().shutdown()

# %% [markdown]
# ### Seperate by Years

# %%
zipcd_wrangled =pd.read_csv("zipcd_wrangled.csv")

# %%
zipcd_wrangled.isnull().sum()
# Out:
# Unnamed: 0                              0
# Practice_Address_Zip5                   0
# city                                    0
# stabbr                                  0
# year                                    0
# total_NPIs                              0
# Total_Claim_Count                       0
# Total_Opioid_Claim_Count                0
# total_2010_pop                          0
# Total_Employees                         0
# Total_Annual_Payroll_1000s              0
# Total_Establishments                    0
# Total_Tax_Returns                       0
# Total_Single_Returns                    0
# Total_Joint_Returns                     0
# Total_HeadOfHousehold_Returns           0
# Total_Dependents                        0
# Total_AGI_1000s                         0
# Total_Income_1000s                      0
# Total_Farm_Returns                      0
# Total_Unemp_Comp_Returns                0
# Total_Mortgate_Interest_Paid_Returns    0
# ...

# %%
zipcd_wrangled
# Out:
#    Unnamed: 0  Practice_Address_Zip5           city stabbr  year  total_NPIs  \
# 0          78                   1001         AGAWAM     MA  2013          32
# 1          81                   1010      BRIMFIELD     MA  2013           6
# 2          82                   1013       CHICOPEE     MA  2013           9
# 3          84                   1026     CUMMINGTON     MA  2013           1
# 4          89                   1088  WEST HATFIELD     MA  2015          10
#
#    Total_Claim_Count  Total_Opioid_Claim_Count  total_2010_pop  \
# 0              56083                      2499         16769.0
# 1               6406                       318          3609.0
# 2                225                         0         23188.0
# 3               1656                        12           946.0
# 4               1128                       439           670.0
#
#    Total_Employees         ...          Total_HeadOfHousehold_Returns  \
# ...

# %%
zipcd2013 = zipcd_wrangled[zipcd_wrangled['year'] == 2013]

# %%
zipcd2014 = zipcd_wrangled[zipcd_wrangled['year'] == 2014]

# %%
zipcd2015 = zipcd_wrangled[zipcd_wrangled['year'] == 2015]
